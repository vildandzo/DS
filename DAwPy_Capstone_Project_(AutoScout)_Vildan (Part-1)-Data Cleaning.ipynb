# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid"
# alt="CLRSWY"></p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#9d4f8c; font-size:100%; text-align:center; border-radius:10px 10px;">WAY TO REINVENT YOURSELF</p>

# %% [markdown]
# <img src=https://i.ibb.co/wJW61Y2/Used-cars.jpg width="700" height="200">
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:200%; text-align:center; border-radius:10px 10px;">The Capstone Project of Data Analytics Module</p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:150%; text-align:center; border-radius:10px 10px;">Car Price Prediction EDA</p>

# %% [markdown]
# ## Introduction
# Welcome to "***AutoScout Data Analysis Project***". This is the capstone project of ***Data Analysis*** Module. **Auto Scout** data which using for this project, scraped from the on-line car trading company in 2019, contains many features of 9 different car models. In this project, you will have the opportunity to apply many commonly used algorithms for Data Cleaning and Exploratory Data Analysis by using many Python libraries such as Numpy, Pandas, Matplotlib, Seaborn, Scipy you will analyze clean dataset.
#
# ### Some Reminders on Exploratory data analysis (EDA)
#
# Exploratory data analysis (EDA) is an especially important activity in the routine of a data analyst or scientist. It enables an in depth understanding of the dataset, define or discard hypotheses and create predictive models on a solid basis. It uses data manipulation techniques and several statistical tools to describe and understand the relationship between variables and how these can impact business. By means of EDA, we can obtain meaningful insights that can impact analysis under the following questions (If a checklist is good enough for pilots to use every flight, it’s good enough for data scientists to use with every dataset).
# 1. What question are you trying to solve (or prove wrong)?
# 2. What kind of data do you have?
# 3. What’s missing from the data?
# 4. Where are the outliers?
# 5. How can you add, change or remove features to get more out of your data?
#
# **``Exploratory data analysis (EDA)``** is often an **iterative brainstorming process** where you pose a question, review the data, and develop further questions to investigate before beginning model development work. The image below shows how the brainstorming phase is connected with that of understanding the variables and how this in turn is connected again with the brainstorming phase.<br>
#
# <img src=https://i.ibb.co/k0MC950/EDA-Process.png width="300" height="100">
#
# [Image Credit: Andrew D.](https://towardsdatascience.com/exploratory-data-analysis-in-python-a-step-by-step-process-d0dfa6bf94ee)
#
# **``In this context, the project consists of 3 parts in general:``**
# * **The first part** is related to 'Data Cleaning'. It deals with Incorrect Headers, Incorrect Format, Anomalies, and Dropping useless columns.
# * **The second part** is related to 'Filling Data', in other words 'Imputation'. It deals with Missing Values. Categorical to numeric transformation is done as well.
# * **The third part** is related to 'Handling Outliers of Data' via Visualization libraries. So, some insights will be extracted.
#
# **``NOTE:``**  However, you are free to create your own style. You do NOT have to stick to the steps above. We, the DA & DV instructors, recommend you study each part separately to create a source notebook for each part title for your further studies.

# %% [markdown]
# # PART- 1 `( Data Cleaning )`

# %% [markdown]
# ## Import Libraries

# %%
import numpy as np
import pandas as pd
from skimpy import clean_columns

import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
from pandas.plotting import register_matplotlib_converters
from pylab import rcParams
sns.set_style("darkgrid")

import plotly 
import plotly.express as px
import plotly.graph_objs as go
import plotly.offline as py
from plotly.offline import iplot
from plotly.subplots import make_subplots
import plotly.figure_factory as ff

# To display maximum columns
pd.set_option('display.max_columns', None)

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Import Data

# %%
df_origin = pd.read_json("./scout_car.json", lines=True)
df = df_origin.copy()
df.head()
# Out:
#                                                  url make_model  \
# 0  https://www.autoscout24.com//offers/audi-a1-sp...    Audi A1
# 1  https://www.autoscout24.com//offers/audi-a1-1-...    Audi A1
# 2  https://www.autoscout24.com//offers/audi-a1-sp...    Audi A1
# 3  https://www.autoscout24.com//offers/audi-a1-1-...    Audi A1
# 4  https://www.autoscout24.com//offers/audi-a1-sp...    Audi A1
#
#                                    short_description body_type  price  \
# 0        Sportback 1.4 TDI S-tronic Xenon Navi Klima    Sedans  15770
# 1                                     1.8 TFSI sport    Sedans  14500
# 2  Sportback 1.6 TDI S tronic Einparkhilfe plus+m...    Sedans  14640
# 3                            1.4 TDi Design S tronic    Sedans  14500
# 4  Sportback 1.4 TDI S-Tronic S-Line Ext. admired...    Sedans  16790
#
#                 vat         km registration         prev_owner  kW      hp  \
# 0    VAT deductible  56,013 km      01/2016  2 previous owners NaN   66 kW
# ...

# %% [markdown]
# ## Data Info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15919 entries, 0 to 15918
# Data columns (total 54 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   url                            15919 non-null  object
#  1   make_model                     15919 non-null  object
#  2   short_description              15873 non-null  object
#  3   body_type                      15859 non-null  object
#  4   price                          15919 non-null  int64
#  5   vat                            11406 non-null  object
#  6   km                             15919 non-null  object
#  7   registration                   15919 non-null  object
#  8   prev_owner                     9091 non-null   object
#  9   kW                             0 non-null      float64
#  10  hp                             15919 non-null  object
#  11  Type                           15917 non-null  object
# ...

# %% [markdown]
# ## Data head and Understanding the data

# %%
df.head().T
# Out:
#                                                                                0  \
# url                            https://www.autoscout24.com//offers/audi-a1-sp...
# make_model                                                               Audi A1
# short_description                    Sportback 1.4 TDI S-tronic Xenon Navi Klima
# body_type                                                                 Sedans
# price                                                                      15770
# vat                                                               VAT deductible
# km                                                                     56,013 km
# registration                                                             01/2016
# prev_owner                                                     2 previous owners
# kW                                                                           NaN
# hp                                                                         66 kW
# ...

# %%
# There is information about 3 brands (Audi,Opel,Renault) in this dataset. 
# There are 3 different models for each brand.

# %% [markdown]
# ## Cleaning the Column Names

# %%
# cleaning column names using skimpy clean_columns method
df = clean_columns(df)
df.columns
# Out:
# 42 column names have been cleaned
# Index(['url', 'make_model', 'short_description', 'body_type', 'price', 'vat',
#        'km', 'registration', 'prev_owner', 'k_w', 'hp', 'type',
#        'previous_owners', 'next_inspection', 'inspection_new', 'warranty',
#        'full_service', 'non_smoking_vehicle', 'null', 'make', 'model',
#        'offer_number', 'first_registration', 'body_color', 'paint_type',
#        'body_color_original', 'upholstery', 'body', 'nr_of_doors',
#        'nr_of_seats', 'model_code', 'gearing_type', 'displacement',
#        'cylinders', 'weight', 'drive_chain', 'fuel', 'consumption',
#        'co_2_emission', 'emission_class', 'comfort_&_convenience',
#        'entertainment_&_media', 'extras', 'safety_&_security', 'description',
#        'emission_label', 'gears', 'country_version', 'electricity_consumption',
#        'last_service_date', 'other_fuel_types', 'availability',
#        'last_timing_belt_service_date', 'available_from'],
#       dtype='object')

# %% [markdown]
# ## Drop Empty Columns

# %%
df["null"].isnull().sum() # all values in the column are an empty list. because of that it will be dropped
# Out:
# 0

# %%
# all values in the "kW" column are null. Because of that it will be dropped
# all values in the "null" column are an empty list. because of that it will be dropped

#df.drop(columns=["k_w","null"],inplace=True)

# %% [markdown]
# ## Changing data type of values in the cells

# %%
# Convert List type object to str type all Column
df = df.applymap(lambda x: ','.join(map(str, x)) if isinstance(x, list) else x)
df
# Out:
#                                                      url      make_model  \
# 0      https://www.autoscout24.com//offers/audi-a1-sp...         Audi A1
# 1      https://www.autoscout24.com//offers/audi-a1-1-...         Audi A1
# 2      https://www.autoscout24.com//offers/audi-a1-sp...         Audi A1
# 3      https://www.autoscout24.com//offers/audi-a1-1-...         Audi A1
# 4      https://www.autoscout24.com//offers/audi-a1-sp...         Audi A1
# ...                                                  ...             ...
# 15914  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15915  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15916  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15917  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15918  https://www.autoscout24.com//offers/renault-es...  Renault Espace
#
#                                        short_description body_type  price  \
# ...

# %% [markdown]
# ## Checking duplicated rows

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Define a func and look each columns properties

# %%
def first_look(col):
    print('column name : ', col)
    print('--------------------------------')
    print('Per_of_Nulls   : ', '%', round(df[col].isnull().sum() / df.shape[0]*100, 2))
    print('Num_of_Nulls   : ', df[col].isnull().sum())
    print('Num_of_Uniques : ', df[col].nunique())
#     print('Duplicates     : ', df.duplicated(subset = None, keep = 'first').sum())
    print(df[col].value_counts(dropna = False))#.sort_index())
    print(df[col].value_counts(dropna = False).sort_index())
    print("##"*20)
    print()

# %%
for i in df.select_dtypes(include="O").columns:
    first_look(i)
# Out:
# column name :  url
# --------------------------------
# Per_of_Nulls   :  % 0.0
# Num_of_Nulls   :  0
# Num_of_Uniques :  15919
# https://www.autoscout24.com//offers/audi-a1-sportback-1-4-tdi-s-tronic-xenon-navi-klima-diesel-black-bdab349a-caa5-41b0-98eb-c1345b84445e                  1
# https://www.autoscout24.com//offers/opel-insignia-bus-inno-2-0-cdti-aut-navi-bi-xe-led-e6-diesel-black-8710b253-dd98-4ed0-9d46-cbad2d79532b                1
# https://www.autoscout24.com//offers/opel-insignia-sport-tourer-opel-sport-tourer-1-6-cdti-136-ch-a-c-diesel-silver-10b7463b-9f56-4348-af35-df3432b2b585    1
# https://www.autoscout24.com//offers/opel-insignia-2-0cdti-st-business-innovation-navi-bt-diesel-black-ba5a3368-dedc-4e51-9127-3976b26e93c2                 1
# https://www.autoscout24.com//offers/opel-insignia-sport-tourer-opel-sport-tourer-1-6-cdti-136-ch-a-c-diesel-silver-7b52f054-78d3-4d5e-9370-8a7d081d7edd    1
# ...

# %% [markdown]
# ### First look analysis

# %%
# "url" will be deleted after all analysis
# There is only one line of data about the Audi A2
# "km" column will be cleared and Data type will be integer.
# There is data in the "registration" column as "-/-"
# "prev_owner" column will clear  and Data type will be integer.
# The "hp" column will be cleared, the integer will be made and small values such as "- kW,1 kW" will be looked at
# The content and name of the "previous owners"  and "prev_owner" columns will be compared. Data type will be integer.
# "next_inspection" null data can be filled, will be cleared. datatype  will be made date.
# "inspection_new" column can be edited as "yes" "no".
# "warranty" column has null and empty data. will be converted to month format and integer.
# "full_service" column has null and empty data.
# "non_smoking_vehicle" column has null and empty data.
# Compare the "make_model" column with the "make" and "model" columns and decide which one to drop.
# "offer_number" will be dropped.
# "first registration" will be looked at according to "registration".
# "body color" nulls will be looked at.
# "paint_type" can be divided into metallic and other.
# "body_color_original" will be dropped.
# "upholstery" will be categorized.
# "body_type" and "body" have the same values, one will be dropped.
# "nr_of_doors" column will look for values 1 and 7.
# "nr_of_seats" column will look for values 1,6,7.
# "model_code" will be dropped.
# "displacement" will be made numerically. commas will be removed. Values such as 1.2, 1.3, 1.4 can be written.
# "cylinders" null values will be checked according to the make_model.
# "weight" column will be made an integer. kg will be deleted. Those who are 1 will be made 1000.
# We can fill the "drive_chain" nans according to the model.
# "fuel" column can be separated as gasoline diesel lpg other.
# "consumption" has been split into 3. It can fill in null values.
# "co_2_emission" and "emission_class" can be studied together.
# "emission_class" nulls will be looked at.
# "comfort_&_convenience" nulls will be looked at.
# "entertaintment_&_media" nulls will be looked at.
# "extras" nulls will be looked at.
# "safety_&_security" can be categorized by creating a package.
# "description" can be viewed as needed.
# "emission label" can be inspected and deducted from other emission columns.
# "gears" outlier and nulls will be checked.
# "country_version" will be dropped.
# "electricity_consumption" will be dropped.
# "last_service_date, other_fuel_types, availability, last_timing_belt_service_date, available_from" will be dropped.

# %%
df[df.select_dtypes(include="O").columns] = df.select_dtypes(include="O").apply(lambda x: x.str.replace(",?\n,?",""))
df.sample(10)
# Out:
#                                                      url     make_model  \
# 9605   https://www.autoscout24.com//offers/opel-corsa...     Opel Corsa
# 10655  https://www.autoscout24.com//offers/opel-insig...  Opel Insignia
# 8036   https://www.autoscout24.com//offers/opel-astra...     Opel Astra
# 6150   https://www.autoscout24.com//offers/opel-astra...     Opel Astra
# 13803  https://www.autoscout24.com//offers/renault-cl...   Renault Clio
# 14559  https://www.autoscout24.com//offers/renault-cl...   Renault Clio
# 5345   https://www.autoscout24.com//offers/audi-a3-sp...        Audi A3
# 7233   https://www.autoscout24.com//offers/opel-astra...     Opel Astra
# 5681   https://www.autoscout24.com//offers/audi-a3-30...        Audi A3
# 12214  https://www.autoscout24.com//offers/opel-insig...  Opel Insignia
#
#                                        short_description      body_type  \
# 9605      1.4 5 porte b-Color Garanzia ufficiale 12 mesi         Sedans
# ...

# %%
# df.describe(include="O").T

# %%
# strip - Strip strange values apart from beginning and end
df = df.applymap(lambda x: x.strip('''\n' ".,-_/][''') if isinstance(x, str) else x)

# %% [markdown]
# ### Replacing empty rows with np.nan

# %%
df["non_smoking_vehicle"][df.non_smoking_vehicle.str.contains(r'^s\*$')==True] = np.nan
df["non_smoking_vehicle"].isnull().sum()
# Out:
# 8742

# %%
df.isin(['']).sum()
# Out:
# url                                  0
# make_model                           0
# short_description                    3
# body_type                            0
# price                                0
# vat                                  0
# km                                   0
# registration                      1597
# prev_owner                           0
# k_w                                  0
# hp                                   0
# type                                 0
# previous_owners                      0
# next_inspection                      0
# inspection_new                       0
# warranty                          1343
# full_service                      1985
# non_smoking_vehicle               3717
# null                             15919
# make                                 0
# model                                0
# offer_number                         0
# first_registration                   0
# body_color                           0
# ...

# %%
df[df.isin([''])]=np.nan

# %%
df.isin(['', '[],[],[]']).sum()
# Out:
# url                              0
# make_model                       0
# short_description                0
# body_type                        0
# price                            0
# vat                              0
# km                               0
# registration                     0
# prev_owner                       0
# k_w                              0
# hp                               0
# type                             0
# previous_owners                  0
# next_inspection                  0
# inspection_new                   0
# warranty                         0
# full_service                     0
# non_smoking_vehicle              0
# null                             0
# make                             0
# model                            0
# offer_number                     0
# first_registration               0
# body_color                       0
# paint_type                       0
# body_color_original              0
# upholstery                       0
# ...

# %%
df.isnull().sum()
# Out:
# url                                  0
# make_model                           0
# short_description                   49
# body_type                           60
# price                                0
# vat                               4513
# km                                   0
# registration                      1597
# prev_owner                        6828
# k_w                              15919
# hp                                   0
# type                                 2
# previous_owners                   6640
# next_inspection                  12384
# inspection_new                   11987
# warranty                          6763
# full_service                      9689
# non_smoking_vehicle              12459
# null                             15919
# make                                 0
# model                                0
# offer_number                      3175
# first_registration                1597
# body_color                         597
# ...

# %%
(df.isnull().sum().div(len(df))*100).sort_values(ascending=False)
# Out:
# other_fuel_types                 100.000000
# null                             100.000000
# k_w                              100.000000
# last_timing_belt_service_date     99.899491
# electricity_consumption           99.139393
# available_from                    98.291350
# last_service_date                 96.444500
# availability                      96.011056
# non_smoking_vehicle               78.264966
# next_inspection                   77.793831
# inspection_new                    75.299956
# emission_label                    75.218293
# model_code                        68.729192
# full_service                      60.864376
# country_version                   52.346253
# weight                            43.809285
# drive_chain                       43.080596
# prev_owner                        42.892141
# warranty                          42.483824
# previous_owners                   41.711163
# paint_type                        36.258559
# ...

# %% [markdown]
# ### Drop columns containing greather than or equal %95 null values

# %%
#Columns with more than 95% null
print(df.shape)
for col in df.columns:
    if (df[col].isnull().sum() / df.shape[0]*100) >= 95:
        print(col)
        print('Per_of_Nulls   : ', '%', round(df[col].isnull().sum() / df.shape[0]*100, 2))
        print("-"*25)
# Out:
# (15919, 54)
# k_w
# Per_of_Nulls   :  % 100.0
# -------------------------
# null
# Per_of_Nulls   :  % 100.0
# -------------------------
# electricity_consumption
# Per_of_Nulls   :  % 99.14
# -------------------------
# last_service_date
# Per_of_Nulls   :  % 96.44
# -------------------------
# other_fuel_types
# Per_of_Nulls   :  % 100.0
# -------------------------
# availability
# Per_of_Nulls   :  % 96.01
# -------------------------
# last_timing_belt_service_date
# Per_of_Nulls   :  % 99.9
# -------------------------
# available_from
# Per_of_Nulls   :  % 98.29
# -------------------------

# %%
print(df.shape)
for col in df.columns:
    if (df[col].isnull().sum() / df.shape[0]*100) >= 95:
        df.drop(col, axis=1, inplace=True)
print(df.shape)
# Out:
# (15919, 54)
# (15919, 46)

# %% [markdown]
# ## Data Cleaning Column by column cleaning

# %%
df.shape
# Out:
# (15919, 46)

# %%
df.columns
# Out:
# Index(['url', 'make_model', 'short_description', 'body_type', 'price', 'vat',
#        'km', 'registration', 'prev_owner', 'hp', 'type', 'previous_owners',
#        'next_inspection', 'inspection_new', 'warranty', 'full_service',
#        'non_smoking_vehicle', 'make', 'model', 'offer_number',
#        'first_registration', 'body_color', 'paint_type', 'body_color_original',
#        'upholstery', 'body', 'nr_of_doors', 'nr_of_seats', 'model_code',
#        'gearing_type', 'displacement', 'cylinders', 'weight', 'drive_chain',
#        'fuel', 'consumption', 'co_2_emission', 'emission_class',
#        'comfort_&_convenience', 'entertainment_&_media', 'extras',
#        'safety_&_security', 'description', 'emission_label', 'gears',
#        'country_version'],
#       dtype='object')

# %% [markdown]
# ### url column

# %%
#We will drop after checking other columns.

# %%
df.url.sample(20)
# Out:
# 13183    https://www.autoscout24.com//offers/renault-cl...
# 5226     https://www.autoscout24.com//offers/audi-a3-sp...
# 14818    https://www.autoscout24.com//offers/renault-cl...
# 8733     https://www.autoscout24.com//offers/opel-corsa...
# 14571    https://www.autoscout24.com//offers/renault-cl...
# 10272    https://www.autoscout24.com//offers/opel-corsa...
# 4837     https://www.autoscout24.com//offers/audi-a3-sp...
# 15514    https://www.autoscout24.com//offers/renault-es...
# 1044     https://www.autoscout24.com//offers/audi-a1-sp...
# 14882    https://www.autoscout24.com//offers/renault-cl...
# 4333     https://www.autoscout24.com//offers/audi-a3-1-...
# 1170     https://www.autoscout24.com//offers/audi-a1-1-...
# 12647    https://www.autoscout24.com//offers/opel-insig...
# 4160     https://www.autoscout24.com//offers/audi-a3-sp...
# 8108     https://www.autoscout24.com//offers/opel-astra...
# 8304     https://www.autoscout24.com//offers/opel-corsa...
# ...

# %%
for i in df.url:
    print(i)
# Out:
# https://www.autoscout24.com//offers/audi-a1-sportback-1-4-tdi-s-tronic-xenon-navi-klima-diesel-black-bdab349a-caa5-41b0-98eb-c1345b84445e
# https://www.autoscout24.com//offers/audi-a1-1-8-tfsi-sport-gasoline-red-b2547f8a-e83f-6237-e053-e250040a56df
# https://www.autoscout24.com//offers/audi-a1-sportback-1-6-tdi-s-tronic-einparkhilfe-plus-music-diesel-black-6183cb6a-8570-4b86-a132-9b54214bca88
# https://www.autoscout24.com//offers/audi-a1-1-4-tdi-design-s-tronic-diesel-brown-35c86585-2727-d61e-e053-e250040ad640
# https://www.autoscout24.com//offers/audi-a1-sportback-1-4-tdi-s-tronic-s-line-ext-admired-xe-diesel-black-b86b55d8-9c7c-4a58-b658-b97008a51efc
# https://www.autoscout24.com//offers/audi-a1-1-6-tdi-sport-dsg-shz-xenon-navi-bose-pdc-diesel-white-9784453b-91e6-4777-b9c5-22efa9217931
# https://www.autoscout24.com//offers/audi-a1-sportback-1-6-tdi-s-tronic-s-line-navi-xenon-diesel-white-7b75e258-dffd-4ce5-b8c5-0b2b34ae29ab
# ...

# %%
#Since url column is unique, we dropped "url" column.
df.drop(columns="url", inplace=True)

# %%
#After dropping url column, lets look duplicated rows:
df.duplicated().sum()
# Out:
# 877

# %%
#Drop the duplicated rows
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (15042, 45)

# %% [markdown]
# ### make_model, make, model columns

# %%
df.make_model
# Out:
# 0               Audi A1
# 1               Audi A1
# 2               Audi A1
# 3               Audi A1
# 4               Audi A1
#               ...
# 15914    Renault Espace
# 15915    Renault Espace
# 15916    Renault Espace
# 15917    Renault Espace
# 15918    Renault Espace
# Name: make_model, Length: 15042, dtype: object

# %%
first_look("make_model")
# Out:
# column name :  make_model
# --------------------------------
# Per_of_Nulls   :  % 0.0
# Num_of_Nulls   :  0
# Num_of_Uniques :  9
# Audi A3           2944
# Audi A1           2490
# Opel Insignia     2479
# Opel Astra        2380
# Opel Corsa        2154
# Renault Clio      1649
# Renault Espace     911
# Renault Duster      34
# Audi A2              1
# Name: make_model, dtype: int64
# Audi A1           2490
# Audi A2              1
# Audi A3           2944
# Opel Astra        2380
# Opel Corsa        2154
# Opel Insignia     2479
# Renault Clio      1649
# Renault Duster      34
# Renault Espace     911
# Name: make_model, dtype: int64
# ########################################

# %%
df[["make_model","make","model"]]
# Out:
#            make_model     make   model
# 0             Audi A1     Audi      A1
# 1             Audi A1     Audi      A1
# 2             Audi A1     Audi      A1
# 3             Audi A1     Audi      A1
# 4             Audi A1     Audi      A1
# ...               ...      ...     ...
# 15914  Renault Espace  Renault  Espace
# 15915  Renault Espace  Renault  Espace
# 15916  Renault Espace  Renault  Espace
# 15917  Renault Espace  Renault  Espace
# 15918  Renault Espace  Renault  Espace
#
# [15042 rows x 3 columns]

# %%
df[["make_model","make","model"]].isna().sum()
# Out:
# make_model    0
# make          0
# model         0
# dtype: int64

# %%
df[["make_model","make","model"]].value_counts()
# Out:
# make_model      make     model
# Audi A3         Audi     A3          2944
# Audi A1         Audi     A1          2490
# Opel Insignia   Opel     Insignia    2479
# Opel Astra      Opel     Astra       2380
# Opel Corsa      Opel     Corsa       2154
# Renault Clio    Renault  Clio        1649
# Renault Espace  Renault  Espace       911
# Renault Duster  Renault  Duster        34
# Audi A2         Audi     A2             1
# dtype: int64

# %%
df.drop(columns="make", inplace=True)

# %%
df.drop(columns="model", inplace=True)

# %%
df.shape
# Out:
# (15042, 43)

# %%
#make- model and make_model columns are the same, so make and model are dropped.

# %% [markdown]
# ### short_description column

# %%
#We will drop after checking other columns.

# %%
df.short_description
# Out:
# 0              Sportback 1.4 TDI S-tronic Xenon Navi Klima
# 1                                           1.8 TFSI sport
# 2        Sportback 1.6 TDI S tronic Einparkhilfe plus+m...
# 3                                  1.4 TDi Design S tronic
# 4        Sportback 1.4 TDI S-Tronic S-Line Ext. admired...
#                                ...
# 15914                Blue dCi 200CV EDC Executive 4Control
# 15915                  TCe 225 EDC GPF LIM Deluxe Pano,RFK
# 15916    Blue dCi 200 EDC Initiale Paris Leder LED Navi...
# 15917    Blue dCi 200CV EDC Business , NUOVA DA IMMATRI...
# 15918          INITIALE PARIS TCe 225 EDC GPF NAVI SHZ AUX
# Name: short_description, Length: 15042, dtype: object

# %%
first_look("short_description")
# Out:
# column name :  short_description
# --------------------------------
# Per_of_Nulls   :  % 0.33
# Num_of_Nulls   :  49
# Num_of_Uniques :  9970
# SPB 1.6 TDI 116 CV S tronic Sport                     64
# NaN                                                   49
# 1.4 66kW (90CV) Selective                             38
# MOVE KLIMA CD USB ALLWETTER BLUETOOTH                 38
# SPB 30 TFSI S tronic Admired                          35
#                                                       ..
# K ST Business 1.6 CDTI AGR-Sitze Navi                  1
# K 1.6 CDTI Innovation T-Leder StHzg Kamera             1
# Sports Tourer BUSINESS 1.6 CDTI 136 ch BVA6 Editio     1
# 1.6 CDTi 136CV aut. Sports Tourer Business my.2017     1
# TCe 225 EDC GPF LIM Deluxe Pano,RFK                    1
# Name: short_description, Length: 9971, dtype: int64
# !! VENDUE VENDUE !!!                                  1
# (2) 1.4 TDI ULTRA 90 AMBIENTE S tronic                1
# ...

# %%
df.groupby(["make_model"])["short_description"].value_counts().head(50)
# Out:
# make_model  short_description
# Audi A1     SPB 30 TFSI S tronic Admired                          34
#             1.0 TFSI ultra Sportback                              19
#             Sportback 1.0 TFSI Adrenalin 70 kW (95 C              19
#             1.0 TFSI                                              18
#             30 TFSI                                               18
#             25 TFSI                                               14
#             Sportback 1.4 TDI design Navi+/Xenon/PDC+/SitzHzg     14
#             30 TFSI advanced exterieur                            13
#             SPB 1.6 TDI 116 CV Metal plus                         12
#             Sportback 25 TFSI Advanced 70 kW (95 CV)              11
#             SPB 30 TFSI S tronic S line edition                   10
#             SPORTBACK 1.0 TFSI 95ch ultra Ambiente S tronic 7     10
#             SB 1,0 TFSI intense                                    9
# ...

# %%
def get_diff_category_column(Series:pd.Series, exclude=''',/\n''', pattern=r'''[,\n]| /''', strip='''\n' "!?|.,*+-_/]['''):
    """
    exclude  - satırlar da kategori ayırım yerleri
    pattern  - satırdaki veriyi ayırma regex
    strip    - alakasız işaretleri kaldırma
    """
    import re
    column = Series.dropna().apply(str).str.strip(strip)
    diff_value = list()
    for row in column:
        if not any(x in exclude for x in row) and row not in diff_value:
            diff_value.append(row)
        else:
            for data in map(lambda x: x.strip(strip), filter(None, re.split(pattern, row))):
                if data not in diff_value:
                    diff_value.append(data)
    return dict(enumerate(sorted(diff_value)))

# %%
import re

# %%
get_diff_category_column(df.short_description)
# Out:
# {0: '(2) 1.4 TDI ULTRA 90 AMBIENTE S tronic',
#  1: '(2) 1.6 CDTI 136 ELITE AUTO',
#  2: '(3E GENERATION) III (2) 1.6 TDI 110 BUSINESS LINE',
#  3: '(4) Air Energy dCi 75',
#  4: '(70 PS)/Radio/Klima/BT/CD',
#  5: '(90 PS)/Klima/PDC/Radio/SHZ',
#  6: '(K',
#  7: '(Klim',
#  8: '(RESERVADO)1.3CDTI 95CV/S&S/LL 15"/LED/BLUETOOTH',
#  9: '(€15900',
#  10: '(€5250',
#  11: '(€5600',
#  12: '(€8600',
#  13: '(€8900',
#  14: '(€8950',
#  15: '(€9250',
#  16: ')',
#  17: '0 66kW Klima',
#  18: '0 AT INNOVATION AFL',
#  19: '0 Autom. MATRIX OPC',
#  20: '0 Blue dCi 200 PS EDC',
#  21: '0 CDTI 125 KW EU6 AT Innovation SHZ Alu',
#  22: '0 CDTI Aut 4x4 Innovat Xen Navi Leder',
#  23: '0 CDTI Aut Navi Bi-Xe Led E6',
#  24: '0 CDTI BlueInj Ultimate',
#  25: '0 CDTI BlueInjection Dynamic St./St. Aut',
#  26: '0 CDTI BlueInjection Innovation S./S. Sy. Au',
#  27: '0 CDTI BlueInjection Innovation St',
#  28: '0 CDTI BlueInjection Innovation St./St. Aut',
# ...

# %% [markdown]
# ### body_type  and body column

# %%
df.body_type
# Out:
# 0        Sedans
# 1        Sedans
# 2        Sedans
# 3        Sedans
# 4        Sedans
#           ...
# 15914       Van
# 15915       Van
# 15916       Van
# 15917       Van
# 15918       Van
# Name: body_type, Length: 15042, dtype: object

# %%
first_look("body_type")
# Out:
# column name :  body_type
# --------------------------------
# Per_of_Nulls   :  % 0.33
# Num_of_Nulls   :  50
# Num_of_Uniques :  9
# Sedans           7478
# Station wagon    3414
# Compact          2903
# Van               731
# Other             289
# Transporter        88
# Off-Road           56
# NaN                50
# Coupe              25
# Convertible         8
# Name: body_type, dtype: int64
# Compact          2903
# Convertible         8
# Coupe              25
# Off-Road           56
# Other             289
# Sedans           7478
# Station wagon    3414
# Transporter        88
# Van               731
# NaN                50
# Name: body_type, dtype: int64
# ########################################

# %%
df[["body_type", "body"]].isnull().sum()
# Out:
# body_type    50
# body         50
# dtype: int64

# %%
df[["body_type", "body"]].value_counts(dropna=False)
# Out:
# body_type      body
# Sedans         Sedans           7478
# Station wagon  Station wagon    3414
# Compact        Compact          2903
# Van            Van               731
# Other          Other             289
# Transporter    Transporter        88
# Off-Road       Off-Road           56
# NaN            NaN                50
# Coupe          Coupe              25
# Convertible    Convertible         8
# dtype: int64

# %%
df.groupby(["make_model"])["body_type"].value_counts(dropna=False)
# Out:
# make_model      body_type
# Audi A1         Sedans           1486
#                 Compact           967
#                 Station wagon      21
#                 Other              13
#                 Coupe               2
#                 Van                 1
# Audi A2         Off-Road            1
# Audi A3         Sedans           2480
#                 Station wagon     282
#                 Compact           148
#                 Other              16
#                 Convertible         8
#                 NaN                 6
#                 Coupe               4
# Opel Astra      Station wagon    1163
#                 Sedans            992
#                 Compact           151
#                 Other              67
#                 NaN                 4
#                 Coupe               2
#                 Off-Road            1
# Opel Corsa      Compact          1192
#                 Sedans            849
#                 Other              87
# ...

# %%
df[df["body_type"].isnull()].head(50)
# Out:
#            make_model                                  short_description  \
# 3175          Audi A3                                            1.6 TDi
# 3255          Audi A3                 1.6 TDI S tronic Business (MY2017)
# 3975          Audi A3                           Sportback Sport S tronic
# 3997          Audi A3  (3E GENERATION) III (2) 1.6 TDI 110 BUSINESS LINE
# 4206          Audi A3                Sportback 1.4 TFSI 125CV Attraction
# 4297          Audi A3                Sportback 1.4 TFSI 125CV Attraction
# 5718       Opel Astra                    1.6 CDTi 136 CV Excellence Auto
# 5940       Opel Astra                    1.6 CDTi 136 CV Excellence Auto
# 6920       Opel Astra                    1.6 CDTi 81kW (110CV) Selective
# 7709       Opel Astra       ELITE 5P 1.4 Turbo 150ch BVA6 MY19.5 (2019A)
# 8408       Opel Corsa                E 1,4 5-tg Easytronic Color Edition
# 8584       Opel Corsa                                               None
# ...

# %%
#body and body_type columns are the same. So we drop body column.
df.drop(columns="body", inplace=True)

# %%
df.shape
# Out:
# (15042, 42)

# %%
df[df["body_type"].isnull()].isnull().sum()
# Out:
# make_model                0
# short_description         1
# body_type                50
# price                     0
# vat                      30
# km                        0
# registration             12
# prev_owner               41
# hp                        0
# type                      0
# previous_owners          41
# next_inspection          47
# inspection_new           49
# warranty                 45
# full_service             48
# non_smoking_vehicle      48
# offer_number             29
# first_registration       12
# body_color                0
# paint_type               40
# body_color_original      17
# upholstery               42
# nr_of_doors               1
# nr_of_seats              37
# model_code               50
# gearing_type              0
# displacement             13
# cylinders                24
# weight                   42
# drive_chain              48
# fuel                      0
# consumption              19
# co_2_emission            19
# ...

# %% [markdown]
# ### price column

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15042 entries, 0 to 15918
# Data columns (total 42 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   make_model             15042 non-null  object
#  1   short_description      14993 non-null  object
#  2   body_type              14992 non-null  object
#  3   price                  15042 non-null  int64
#  4   vat                    10953 non-null  object
#  5   km                     15042 non-null  object
#  6   registration           13547 non-null  object
#  7   prev_owner             8647 non-null   object
#  8   hp                     15042 non-null  object
#  9   type                   15040 non-null  object
#  10  previous_owners        8834 non-null   object
#  11  next_inspection        3436 non-null   object
#  12  inspection_new         3811 non-null   object
#  13  warranty               8728 non-null   object
# ...

# %%
first_look("price")
# Out:
# column name :  price
# --------------------------------
# Per_of_Nulls   :  % 0.0
# Num_of_Nulls   :  0
# Num_of_Uniques :  2956
# 14990    128
# 15990    124
# 10990    114
# 15900    105
# 17990    101
#         ...
# 22185      1
# 22475      1
# 22555      1
# 22615      1
# 39875      1
# Name: price, Length: 2956, dtype: int64
# 13       1
# 120      1
# 255      1
# 331      1
# 4950     1
#         ..
# 64332    1
# 64900    1
# 67600    1
# 68320    1
# 74600    1
# Name: price, Length: 2956, dtype: int64
# ########################################

# %%
df["price"] = df.price.astype(float)

# %% [markdown]
# ### vat column

# %%
df.vat
# Out:
# 0          VAT deductible
# 1        Price negotiable
# 2          VAT deductible
# 3                    None
# 4                    None
#                ...
# 15914      VAT deductible
# 15915      VAT deductible
# 15916      VAT deductible
# 15917      VAT deductible
# 15918      VAT deductible
# Name: vat, Length: 15042, dtype: object

# %%
first_look("vat")
# Out:
# column name :  vat
# --------------------------------
# Per_of_Nulls   :  % 27.18
# Num_of_Nulls   :  4089
# Num_of_Uniques :  2
# VAT deductible      10527
# NaN                  4089
# Price negotiable      426
# Name: vat, dtype: int64
# Price negotiable      426
# VAT deductible      10527
# NaN                  4089
# Name: vat, dtype: int64
# ########################################

# %% [markdown]
# ### km column

# %%
df.km
# Out:
# 0        56,013 km
# 1        80,000 km
# 2        83,450 km
# 3        73,000 km
# 4        16,200 km
#            ...
# 15914           km
# 15915     9,900 km
# 15916        15 km
# 15917        10 km
# 15918           km
# Name: km, Length: 15042, dtype: object

# %%
first_look("km")
# Out:
# column name :  km
# --------------------------------
# Per_of_Nulls   :  % 0.0
# Num_of_Nulls   :  0
# Num_of_Uniques :  6690
# km          969
# 10 km       965
# 1 km        349
# 5 km        161
# 100 km      139
#            ...
# 54 km         1
# 42 km         1
# 1,794 km      1
# 5,586 km      1
# 57 km         1
# Name: km, Length: 6690, dtype: int64
# 0 km         18
# 1 km        349
# 1,000 km     46
# 1,001 km      4
# 1,010 km      1
#            ...
# 990 km        2
# 991 km        1
# 995 km        1
# 999 km        3
# km          969
# Name: km, Length: 6690, dtype: int64
# ########################################

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15042 entries, 0 to 15918
# Data columns (total 42 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   make_model             15042 non-null  object
#  1   short_description      14993 non-null  object
#  2   body_type              14992 non-null  object
#  3   price                  15042 non-null  float64
#  4   vat                    10953 non-null  object
#  5   km                     15042 non-null  object
#  6   registration           13547 non-null  object
#  7   prev_owner             8647 non-null   object
#  8   hp                     15042 non-null  object
#  9   type                   15040 non-null  object
#  10  previous_owners        8834 non-null   object
#  11  next_inspection        3436 non-null   object
#  12  inspection_new         3811 non-null   object
#  13  warranty               8728 non-null   object
# ...

# %%
df["km"] = df.km.str.strip(" km").str.replace(",","").replace(r"", np.nan, regex=True).astype(float)

# %%
first_look("km")
# Out:
# column name :  km
# --------------------------------
# Per_of_Nulls   :  % 6.44
# Num_of_Nulls   :  969
# Num_of_Uniques :  6689
# NaN       969
# 10.0      965
# 1.0       349
# 5.0       161
# 100.0     139
#          ...
# 54.0        1
# 42.0        1
# 1794.0      1
# 5586.0      1
# 57.0        1
# Name: km, Length: 6690, dtype: int64
# 0.0          18
# 1.0         349
# 2.0           6
# 3.0          33
# 4.0          15
#            ...
# 248000.0      1
# 260000.0      1
# 291800.0      1
# 317000.0      1
# NaN         969
# Name: km, Length: 6690, dtype: int64
# ########################################

# %% [markdown]
# ### registration and first_registration columns

# %%
df.registration
# Out:
# 0        01/2016
# 1        03/2017
# 2        02/2016
# 3        08/2016
# 4        05/2016
#           ...
# 15914        NaN
# 15915    01/2019
# 15916    03/2019
# 15917    06/2019
# 15918    01/2019
# Name: registration, Length: 15042, dtype: object

# %%
first_look("registration")
# Out:
# column name :  registration
# --------------------------------
# Per_of_Nulls   :  % 9.94
# Num_of_Nulls   :  1495
# Num_of_Uniques :  47
# NaN        1495
# 03/2018     687
# 02/2019     558
# 05/2018     557
# 03/2019     538
# 04/2018     534
# 01/2019     532
# 02/2018     527
# 03/2016     526
# 06/2018     522
# 04/2016     495
# 04/2019     485
# 01/2018     474
# 05/2019     431
# 03/2017     431
# 02/2016     426
# 06/2016     418
# 05/2016     391
# 07/2018     384
# 06/2017     365
# 01/2016     363
# 04/2017     345
# 05/2017     340
# 02/2017     333
# 01/2017     293
# 08/2018     269
# 06/2019     224
# 07/2017     187
# 11/2017     180
# 07/2016     166
# 10/2016     153
# 10/2017     143
# 09/2017     139
# 09/2018     135
# 11/2016     131
# 09/2016     129
# 12/2017     119
# 11/2018     110
# 12/2016     108
# 08/2017     103
# 10/2018      96
# 12/2018      93
# 08/2016      93
# 07/2019       6
# 09/2019       5
# 08/2019       1
# 11/2019       1
# ...

# %%
df.columns
# Out:
# Index(['make_model', 'short_description', 'body_type', 'price', 'vat', 'km',
#        'registration', 'prev_owner', 'hp', 'type', 'previous_owners',
#        'next_inspection', 'inspection_new', 'warranty', 'full_service',
#        'non_smoking_vehicle', 'offer_number', 'first_registration',
#        'body_color', 'paint_type', 'body_color_original', 'upholstery',
#        'nr_of_doors', 'nr_of_seats', 'model_code', 'gearing_type',
#        'displacement', 'cylinders', 'weight', 'drive_chain', 'fuel',
#        'consumption', 'co_2_emission', 'emission_class',
#        'comfort_&_convenience', 'entertainment_&_media', 'extras',
#        'safety_&_security', 'description', 'emission_label', 'gears',
#        'country_version'],
#       dtype='object')

# %%
df[["registration", "first_registration"]].value_counts(dropna=False)
# Out:
# registration  first_registration
# NaN           NaN                   1495
# 03/2018       2018                   687
# 02/2019       2019                   558
# 05/2018       2018                   557
# 03/2019       2019                   538
# 04/2018       2018                   534
# 01/2019       2019                   532
# 02/2018       2018                   527
# 03/2016       2016                   526
# 06/2018       2018                   522
# 04/2016       2016                   495
# 04/2019       2019                   485
# 01/2018       2018                   474
# 03/2017       2017                   431
# 05/2019       2019                   431
# 02/2016       2016                   426
# 06/2016       2016                   418
# 05/2016       2016                   391
# 07/2018       2018                   384
# 06/2017       2017                   365
# 01/2016       2016                   363
# 04/2017       2017                   345
# ...

# %%
df.groupby(["make_model", "first_registration", "registration"])["price"].describe().head(40)
# Out:
#                                             count          mean          std  \
# make_model first_registration registration
# Audi A1    2016               01/2016        45.0  14561.288889  1889.311546
#                               02/2016        88.0  14262.397727  1749.905571
#                               03/2016       112.0  14371.035714  1785.424521
#                               04/2016        95.0  14662.305263  1939.271546
#                               05/2016        56.0  14832.107143  2247.749522
#                               06/2016        49.0  13990.469388  2192.917132
#                               07/2016        33.0  14362.787879  2210.322894
#                               08/2016        13.0  13911.076923  1726.664195
#                               09/2016        19.0  14344.473684  1973.028703
#                               10/2016        38.0  14228.052632  1953.543156
#                               11/2016        14.0  15131.285714  2365.787247
# ...

# %%
df.drop(columns="registration", inplace=True)

# %%
df["first_registration"] = df.first_registration.astype(float)

# %%
df.shape
# Out:
# (15042, 41)

# %%
df.columns
# Out:
# Index(['make_model', 'short_description', 'body_type', 'price', 'vat', 'km',
#        'prev_owner', 'hp', 'type', 'previous_owners', 'next_inspection',
#        'inspection_new', 'warranty', 'full_service', 'non_smoking_vehicle',
#        'offer_number', 'first_registration', 'body_color', 'paint_type',
#        'body_color_original', 'upholstery', 'nr_of_doors', 'nr_of_seats',
#        'model_code', 'gearing_type', 'displacement', 'cylinders', 'weight',
#        'drive_chain', 'fuel', 'consumption', 'co_2_emission', 'emission_class',
#        'comfort_&_convenience', 'entertainment_&_media', 'extras',
#        'safety_&_security', 'description', 'emission_label', 'gears',
#        'country_version'],
#       dtype='object')

# %% [markdown]
# ### prev_owner and previous owners columns

# %%
df.prev_owner
# Out:
# 0        2 previous owners
# 1                     None
# 2         1 previous owner
# 3         1 previous owner
# 4         1 previous owner
#                ...
# 15914                 None
# 15915     1 previous owner
# 15916     1 previous owner
# 15917                 None
# 15918     1 previous owner
# Name: prev_owner, Length: 15042, dtype: object

# %%
df[["prev_owner", "previous_owners", 'consumption']].sample(50)
# Out:
#               prev_owner previous_owners  \
# 4474                None             NaN
# 14885               None             NaN
# 4734    1 previous owner               1
# 11781               None             NaN
# 11468   1 previous owner               1
# 15719   1 previous owner               1
# 12185   1 previous owner               1
# 1532    1 previous owner               1
# 14898               None             NaN
# 12678               None             NaN
# 6163    1 previous owner               1
# 898                 None             NaN
# 10070   1 previous owner               1
# 13962  2 previous owners               2
# 7946    1 previous owner               1
# 10822               None             NaN
# 6300    1 previous owner               1
# 3850                None             NaN
# 8606    1 previous owner               1
# 1202                None             NaN
# 15607   1 previous owner               1
# 4044    1 previous owner               1
# ...

# %%
df.shape
# Out:
# (15042, 41)

# %%
first_look("prev_owner")
# Out:
# column name :  prev_owner
# --------------------------------
# Per_of_Nulls   :  % 42.51
# Num_of_Nulls   :  6395
# Num_of_Uniques :  4
# 1 previous owner     7977
# NaN                  6395
# 2 previous owners     651
# 3 previous owners      17
# 4 previous owners       2
# Name: prev_owner, dtype: int64
# 1 previous owner     7977
# 2 previous owners     651
# 3 previous owners      17
# 4 previous owners       2
# NaN                  6395
# Name: prev_owner, dtype: int64
# ########################################

# %%
df["prev_owner"] = df.prev_owner.str.extract("(\d)").astype(float)

# %%
df.prev_owner
# Out:
# 0        2.0
# 1        NaN
# 2        1.0
# 3        1.0
# 4        1.0
#         ...
# 15914    NaN
# 15915    1.0
# 15916    1.0
# 15917    NaN
# 15918    1.0
# Name: prev_owner, Length: 15042, dtype: float64

# %% [markdown]
# ### hp column

# %%
df.hp
# Out:
# 0         66 kW
# 1        141 kW
# 2         85 kW
# 3         66 kW
# 4         66 kW
#           ...
# 15914    147 kW
# 15915    165 kW
# 15916    146 kW
# 15917    147 kW
# 15918    165 kW
# Name: hp, Length: 15042, dtype: object

# %%
first_look("hp")
# Out:
# column name :  hp
# --------------------------------
# Per_of_Nulls   :  % 0.0
# Num_of_Nulls   :  0
# Num_of_Uniques :  81
# 85 kW     2422
# 66 kW     2067
# 81 kW     1328
# 100 kW    1246
# 110 kW    1052
#           ...
# 84 kW        1
# 195 kW       1
# 44 kW        1
# 239 kW       1
# 137 kW       1
# Name: hp, Length: 81, dtype: int64
# 1 kW        20
# 100 kW    1246
# 101 kW      33
# 103 kW     223
# 104 kW       8
#           ...
# 92 kW      397
# 93 kW        3
# 96 kW       70
# 98 kW        3
# kW          88
# Name: hp, Length: 81, dtype: int64
# ########################################

# %%
df["hp_kw"] = df.hp.str.extract(r"(\d+)")

# %%
df.hp_kw.isnull().sum()
# Out:
# 88

# %%
df.drop(columns="hp", inplace=True)

# %%
df.shape
# Out:
# (15042, 41)

# %%
df["hp_kw"] = df["hp_kw"].astype(float)

# %%
df.hp_kw
# Out:
# 0         66.0
# 1        141.0
# 2         85.0
# 3         66.0
# 4         66.0
#          ...
# 15914    147.0
# 15915    165.0
# 15916    146.0
# 15917    147.0
# 15918    165.0
# Name: hp_kw, Length: 15042, dtype: float64

# %%
df.groupby(["make_model"])["hp_kw"].value_counts().head(30)
# Out:
# make_model  hp_kw
# Audi A1     85.0      837
#             70.0      780
#             66.0      438
#             60.0      156
#             92.0      145
#             71.0       54
#             110.0      30
#             141.0      16
#             147.0      14
#             67.0       10
#             93.0        3
#             87.0        2
#             86.0        1
#             112.0       1
#             140.0       1
# Audi A2     85.0        1
# Audi A3     85.0     1562
#             81.0      763
#             110.0     476
#             92.0       62
#             135.0      22
#             294.0      18
#             82.0       13
#             96.0        9
#             87.0        4
#             228.0       2
#             270.0       2
#             9.0         1
#             86.0        1
#             100.0       1
# Name: hp_kw, dtype: int64

# %% [markdown]
# ### type column

# %%
df.type
# Out:
# 0                        Used,,Diesel (Particulate Filter)
# 1                                           Used,,Gasoline
# 2                        Used,,Diesel (Particulate Filter)
# 3                        Used,,Diesel (Particulate Filter)
# 4                        Used,,Diesel (Particulate Filter)
#                                ...
# 15914                     New,,Diesel (Particulate Filter)
# 15915    Used,,Super 95 / Super Plus 98 (Particulate Fi...
# 15916                               Pre-registered,,Diesel
# 15917                               Pre-registered,,Diesel
# 15918                              Demonstration,,Super 95
# Name: type, Length: 15042, dtype: object

# %%
first_look("type")
# Out:
# column name :  type
# --------------------------------
# Per_of_Nulls   :  % 0.01
# Num_of_Nulls   :  2
# Num_of_Uniques :  169
# Used,,Diesel (Particulate Filter)                                                                                 3231
# Used,,Diesel                                                                                                      2404
# Used,,Gasoline                                                                                                    2168
# Used,,Super 95                                                                                                    1723
# New,,Super 95                                                                                                      490
#                                                                                                                   ...
# New,,Regular/Benzine 91 / Super 95 / Super Plus 98 / Regular/Benzine E10 91 / Super Plus E10 98 / Super E10 95       1
# ...

# %%
df[["type", "fuel"]].head(50)
# Out:
#                                            type                         fuel
# 0             Used,,Diesel (Particulate Filter)  Diesel (Particulate Filter)
# 1                                Used,,Gasoline                     Gasoline
# 2             Used,,Diesel (Particulate Filter)  Diesel (Particulate Filter)
# 3             Used,,Diesel (Particulate Filter)  Diesel (Particulate Filter)
# 4             Used,,Diesel (Particulate Filter)  Diesel (Particulate Filter)
# 5             Used,,Diesel (Particulate Filter)  Diesel (Particulate Filter)
# 6             Used,,Diesel (Particulate Filter)  Diesel (Particulate Filter)
# 7             Used,,Diesel (Particulate Filter)  Diesel (Particulate Filter)
# 8             Used,,Diesel (Particulate Filter)  Diesel (Particulate Filter)
# 9                                Used,,Gasoline                     Gasoline
# 10            Used,,Diesel (Particulate Filter)  Diesel (Particulate Filter)
# ...

# %%
df.type.str.split(",").str[0].value_counts(dropna=False)
# Out:
# Used              10435
# New                1548
# Pre-registered     1287
# Employee's car      976
# Demonstration       794
# NaN                   2
# Name: type, dtype: int64

# %%
df["type"] = df.type.str.split(",").str[0]

# %%
df.type
# Out:
# 0                  Used
# 1                  Used
# 2                  Used
# 3                  Used
# 4                  Used
#               ...
# 15914               New
# 15915              Used
# 15916    Pre-registered
# 15917    Pre-registered
# 15918     Demonstration
# Name: type, Length: 15042, dtype: object

# %% [markdown]
# ### next_inspection column

# %%
df.next_inspection
# Out:
# 0         06/202199 g CO2/km (comb)
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
#                     ...
# 15914                           NaN
# 15915    01/2022168 g CO2/km (comb)
# 15916                           NaN
# 15917                           NaN
# 15918                           NaN
# Name: next_inspection, Length: 15042, dtype: object

# %%
first_look("next_inspection")
# Out:
# column name :  next_inspection
# --------------------------------
# Per_of_Nulls   :  % 77.16
# Num_of_Nulls   :  11606
# Num_of_Uniques :  1384
# NaN                                                                  11606
# 04/2022                                                                 62
# 06/2021                                                                 47
# 03/2021                                                                 39
# 03/2022                                                                 36
#                                                                      ...
# 04/20214.7 l/100 km (comb)5.8 l/100 km (city)4 l/100 km (country)        1
# 05/2020139 g CO2/km (comb)                                               1
# 08/2020Euro 6                                                            1
# 12/2020126 g CO2/km (comb)                                               1
# 01/2022168 g CO2/km (comb)                                               1
# ...

# %%
df.next_inspection.str.extract(r"(\d+/\d{0,4})").head(30)
# Out:
#           0
# 0   06/2021
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# 5       NaN
# 6       NaN
# 7       NaN
# 8   02/2020
# 9       NaN
# 10      NaN
# 11      NaN
# 12  09/2019
# 13      NaN
# 14  10/2019
# 15  04/2020
# 16      NaN
# 17      NaN
# 18  07/2020
# 19      NaN
# 20      NaN
# 21      NaN
# 22  12/2019
# 23      NaN
# 24      NaN
# 25      NaN
# 26      NaN
# 27      NaN
# 28      NaN
# 29      NaN

# %%
df["next_insp_date"] = df.next_inspection.str.extract(r"(\d+/\d{0,4})")

# %%
df.next_insp_date.isnull().sum()
# Out:
# 11606

# %%
#kolon ismini değiştirdik ama en son silebilirz.

# %% [markdown]
# ### inspection_new column

# %%
df.inspection_new
# Out:
# 0                     YesEuro 6
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4        Yes109 g CO2/km (comb)
#                   ...
# 15914                       NaN
# 15915                       NaN
# 15916           YesEuro 6d-TEMP
# 15917                       NaN
# 15918    Yes153 g CO2/km (comb)
# Name: inspection_new, Length: 15042, dtype: object

# %%
df["insp_new"] = df.inspection_new.str.extract(r"(Yes)")

# %%
df.insp_new
# Out:
# 0        Yes
# 1        NaN
# 2        NaN
# 3        NaN
# 4        Yes
#         ...
# 15914    NaN
# 15915    NaN
# 15916    Yes
# 15917    NaN
# 15918    Yes
# Name: insp_new, Length: 15042, dtype: object

# %%
df.insp_new.isnull().sum()
# Out:
# 11231

# %%
# inspection_new kolunu ihtiya. olursa kullan sonra düş.

# %% [markdown]
# ### warranty column

# %%
df.warranty
# Out:
# 0                 4 (Green)
# 1                       NaN
# 2        99 g CO2/km (comb)
# 3                       NaN
# 4                    Euro 6
#                 ...
# 15914             24 months
# 15915                Euro 6
# 15916             4 (Green)
# 15917                   NaN
# 15918                   NaN
# Name: warranty, Length: 15042, dtype: object

# %%
first_look("warranty")
# Out:
# column name :  warranty
# --------------------------------
# Per_of_Nulls   :  % 41.98
# Num_of_Nulls   :  6314
# Num_of_Uniques :  505
# NaN                                                                    6314
# Euro 6                                                                 1830
# 12 months                                                              1078
# 24 months                                                               556
# 4 (Green)                                                               516
#                                                                        ...
# 2 months                                                                  1
# 72 months125 g CO2/km (comb)                                              1
# 60 months14 g CO2/km (comb)                                               1
# 24 months121 g CO2/km (comb)                                              1
# 36 months7.4 l/100 km (comb)9.6 l/100 km (city)6 l/100 km (country)       1
# ...

# %%
df.warranty.str.contains("year", case=False).sum()
# Out:
# 0

# %%
df.warranty.str.contains("month", case=False).sum()
# Out:
# 4521

# %%
df.warranty.str.extract(r"(\d+) month").notna().sum()
# Out:
# 0    4521
# dtype: int64

# %%
df["warranty_month"] = df.warranty.str.extract(r"(\d+) month") # extract(r"(\d+)\s*month")

# %%
df.warranty_month.value_counts(dropna=False)
# Out:
# NaN    10521
# 12      2336
# 24      1075
# 60       392
# 36       261
# 48       145
# 6        125
# 72        59
# 3         33
# 23        11
# 18        10
# 20         7
# 25         6
# 2          5
# 50         4
# 26         4
# 16         4
# 4          3
# 1          3
# 19         3
# 34         3
# 13         3
# 28         2
# 22         2
# 14         2
# 11         2
# 46         2
# 21         2
# 9          2
# 17         2
# 45         2
# 33         1
# 40         1
# 65         1
# 10         1
# 15         1
# 7          1
# 8          1
# 56         1
# 49         1
# 47         1
# 30         1
# Name: warranty_month, dtype: int64

# %%
df["warranty_month"] = df["warranty_month"].astype(float)

# %%
#warranty column will be dropped.

# %% [markdown]
# ### full_service column

# %%
df.full_service
# Out:
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3        99 g CO2/km (comb)
# 4                 4 (Green)
#                 ...
# 15914                   NaN
# 15915                   NaN
# 15916                   NaN
# 15917                   NaN
# 15918                   NaN
# Name: full_service, Length: 15042, dtype: object

# %%
df.full_service.value_counts()
# Out:
# 4 (Green)                                                       2172
# Euro 6                                                          2087
# Euro 6d-TEMP                                                     381
# 120 g CO2/km (comb)                                               67
# 99 g CO2/km (comb)                                                60
#                                                                 ...
# 84 g CO2/km (comb)                                                 1
# 87 g CO2/km (comb)                                                 1
# 5.4 l/100 km (comb)                                                1
# 5.7 l/100 km (comb)7.3 l/100 km (city)4.9 l/100 km (country)       1
# Euro 4                                                             1
# Name: full_service, Length: 120, dtype: int64

# %%
first_look("full_service")
# Out:
# column name :  full_service
# --------------------------------
# Per_of_Nulls   :  % 61.1
# Num_of_Nulls   :  9190
# Num_of_Uniques :  120
# NaN                                                             9190
# 4 (Green)                                                       2172
# Euro 6                                                          2087
# Euro 6d-TEMP                                                     381
# 120 g CO2/km (comb)                                               67
#                                                                 ...
# 84 g CO2/km (comb)                                                 1
# 87 g CO2/km (comb)                                                 1
# 5.4 l/100 km (comb)                                                1
# 5.7 l/100 km (comb)7.3 l/100 km (city)4.9 l/100 km (country)       1
# Euro 4                                                             1
# Name: full_service, Length: 121, dtype: int64
# 0 kWh/100 km (comb)       2
# ...

# %%
#df.drop(columns="full_service", inplace=True)

# %% [markdown]
# ### non_smoking_vehicle column

# %%
df.shape
# Out:
# (15042, 44)

# %%
df.columns
# Out:
# Index(['make_model', 'short_description', 'body_type', 'price', 'vat', 'km',
#        'prev_owner', 'type', 'previous_owners', 'next_inspection',
#        'inspection_new', 'warranty', 'full_service', 'non_smoking_vehicle',
#        'offer_number', 'first_registration', 'body_color', 'paint_type',
#        'body_color_original', 'upholstery', 'nr_of_doors', 'nr_of_seats',
#        'model_code', 'gearing_type', 'displacement', 'cylinders', 'weight',
#        'drive_chain', 'fuel', 'consumption', 'co_2_emission', 'emission_class',
#        'comfort_&_convenience', 'entertainment_&_media', 'extras',
#        'safety_&_security', 'description', 'emission_label', 'gears',
#        'country_version', 'hp_kw', 'next_insp_date', 'insp_new',
#        'warranty_month'],
#       dtype='object')

# %%
df.non_smoking_vehicle
# Out:
# 0              NaN
# 1              NaN
# 2              NaN
# 3           Euro 6
# 4              NaN
#            ...
# 15914          NaN
# 15915    4 (Green)
# 15916          NaN
# 15917          NaN
# 15918          NaN
# Name: non_smoking_vehicle, Length: 15042, dtype: object

# %%
df.non_smoking_vehicle.value_counts()
# Out:
# 4 (Green)                                                       1237
# Euro 6                                                           845
# Euro 6d-TEMP                                                     345
# 120 g CO2/km (comb)                                               37
# 107 g CO2/km (comb)                                               36
#                                                                 ...
# 158 g CO2/km (comb)                                                1
# 150 g CO2/km (comb)                                                1
# 6.2 l/100 km (comb)7.9 l/100 km (city)5.3 l/100 km (country)       1
# 6.5 l/100 km (comb)8.5 l/100 km (city)5.4 l/100 km (country)       1
# 175 g CO2/km (comb)                                                1
# Name: non_smoking_vehicle, Length: 92, dtype: int64

# %%
first_look("non_smoking_vehicle")
# Out:
# column name :  non_smoking_vehicle
# --------------------------------
# Per_of_Nulls   :  % 79.9
# Num_of_Nulls   :  12019
# Num_of_Uniques :  92
# NaN                                                             12019
# 4 (Green)                                                        1237
# Euro 6                                                            845
# Euro 6d-TEMP                                                      345
# 120 g CO2/km (comb)                                                37
#                                                                 ...
# 6.2 l/100 km (comb)7.9 l/100 km (city)5.3 l/100 km (country)        1
# 91 g CO2/km (comb)                                                  1
# 6.5 l/100 km (comb)8.5 l/100 km (city)5.4 l/100 km (country)        1
# 5.7 l/100 km (comb)7.3 l/100 km (city)4.7 l/100 km (country)        1
# 175 g CO2/km (comb)                                                 1
# Name: non_smoking_vehicle, Length: 93, dtype: int64
# ...

# %%
#We will use non_smoking_vehicle column to fill the other columns. After then we will drop it.

# %% [markdown]
# ### offer_number column

# %%
first_look("offer_number")
# Out:
# column name :  offer_number
# --------------------------------
# Per_of_Nulls   :  % 20.74
# Num_of_Nulls   :  3119
# Num_of_Uniques :  11438
# NaN               3119
# BA344433            19
# BR727019            19
# BA863083            19
# BA804713            19
#                   ...
# 58253591             1
# 74045                1
# 57124312             1
# 2466972              1
# Re_30000008029       1
# Name: offer_number, Length: 11439, dtype: int64
# # 250678          1
# # 8H6050830       1
# # G1024529        1
# # G6050580        1
# #8023778          2
#                ...
# x_45689v          2
# y8fx64x           1
# zr11914           1
# zr11916           1
# NaN            3119
# Name: offer_number, Length: 11439, dtype: int64
# ########################################

# %%
#There isn't important info in this columns. So we dropped it.
df.drop(columns="offer_number", inplace=True)

# %%
df.shape
# Out:
# (15042, 43)

# %%
df.columns
# Out:
# Index(['make_model', 'short_description', 'body_type', 'price', 'vat', 'km',
#        'prev_owner', 'type', 'previous_owners', 'next_inspection',
#        'inspection_new', 'warranty', 'full_service', 'non_smoking_vehicle',
#        'first_registration', 'body_color', 'paint_type', 'body_color_original',
#        'upholstery', 'nr_of_doors', 'nr_of_seats', 'model_code',
#        'gearing_type', 'displacement', 'cylinders', 'weight', 'drive_chain',
#        'fuel', 'consumption', 'co_2_emission', 'emission_class',
#        'comfort_&_convenience', 'entertainment_&_media', 'extras',
#        'safety_&_security', 'description', 'emission_label', 'gears',
#        'country_version', 'hp_kw', 'next_insp_date', 'insp_new',
#        'warranty_month'],
#       dtype='object')

# %% [markdown]
# ### body_color column

# %%
first_look("body_color")
# Out:
# column name :  body_color
# --------------------------------
# Per_of_Nulls   :  % 3.62
# Num_of_Nulls   :  544
# Num_of_Uniques :  14
# Black     3583
# Grey      3331
# White     3159
# Silver    1580
# Blue      1374
# Red        866
# NaN        544
# Brown      278
# Green      149
# Beige       98
# Yellow      51
# Violet      18
# Bronze       6
# Orange       3
# Gold         2
# Name: body_color, dtype: int64
# Beige       98
# Black     3583
# Blue      1374
# Bronze       6
# Brown      278
# Gold         2
# Green      149
# Grey      3331
# Orange       3
# Red        866
# Silver    1580
# Violet      18
# White     3159
# Yellow      51
# NaN        544
# Name: body_color, dtype: int64
# ########################################

# %% [markdown]
# ### paint_type column

# %%
first_look("paint_type")
# Out:
# column name :  paint_type
# --------------------------------
# Per_of_Nulls   :  % 36.04
# Num_of_Nulls   :  5421
# Num_of_Uniques :  3
# Metallic       9270
# NaN            5421
# Uni/basic       345
# Perl effect       6
# Name: paint_type, dtype: int64
# Metallic       9270
# Perl effect       6
# Uni/basic       345
# NaN            5421
# Name: paint_type, dtype: int64
# ########################################

# %% [markdown]
# ### body_color_original column

# %%
first_look("body_color_original")
# Out:
# column name :  body_color_original
# --------------------------------
# Per_of_Nulls   :  % 21.73
# Num_of_Nulls   :  3268
# Num_of_Uniques :  1915
# NaN                              3268
# Onyx Schwarz                      335
# Mythosschwarz Metallic            235
# Bianco                            212
# Brillantschwarz                   210
#                                  ...
# mythosschwarz perl                  1
# White & Black                       1
# BLAU                                1
# Schneeweiss / Dach Schwarz          1
# Perlmutt-Weiß Metallic (Weiß)       1
# Name: body_color_original, Length: 1916, dtype: int64
# (0C0C) Monsungrau Metallic        1
# (B4B4) Cortinaweiss               1
# (NNP)                             1
# (Silber) - Licht Grau             2
# (weiß) Abalone Weiss              1
#                                ...
# wählbar - ggf. mit Aufpreis     118
# wählbar -ggfl. mit Aufpreis       1
# wählbar, ggf gegen Aufpreis       2
# ...

# %%
df[["body_color_original", "paint_type", "body_color"]].sample(50)
# Out:
#                   body_color_original paint_type body_color
# 4403                             GRIS        NaN       Grey
# 5902   SchneeWeiss/SummitWhite/Arctic   Metallic      White
# 11670            Gris Espacial (mica)        NaN       Grey
# 15913                  perlmutt-weiss   Metallic      White
# 9924                              NaN        NaN      White
# 12589           Onyx Schwarz-metallic   Metallic      Black
# 9422                            Negro        NaN      Black
# 9246                         Plateado   Metallic     Silver
# 15517                     NERO ETOILE   Metallic      Black
# 13807                             NaN        NaN      White
# 7099                       Quarz Grau   Metallic       Grey
# 10008                    onyx schwarz   Metallic      Black
# 13067                          Bianco        NaN      White
# 12125                     SchneeWeiss        NaN      White
# 750                              gris   Metallic       Grey
# ...

# %% [markdown]
# ### upholstery column

# %%
first_look("upholstery")
# Out:
# column name :  upholstery
# --------------------------------
# Per_of_Nulls   :  % 23.67
# Num_of_Nulls   :  3561
# Num_of_Uniques :  46
# Cloth, Black           5642
# NaN                    3561
# Part leather, Black    1040
# Cloth                   967
# Cloth, Grey             826
# Cloth, Other            633
# Full leather, Black     557
# Black                   357
# Other, Other            156
# Grey                    156
# Full leather            138
# Part leather            134
# Full leather, Brown     114
# Other, Black            107
# Part leather, Grey       91
# Full leather, Other      69
# Part leather, Other      64
# Full leather, Grey       59
# Other                    54
# Part leather, Brown      50
# alcantara, Black         47
# Velour, Black            36
# Full leather, Beige      35
# Cloth, Brown             28
# Velour                   16
# Other, Grey              15
# Cloth, Beige             13
# Brown                    12
# ...

# %%
#df.upholstery.str.extract(r"(.+),(.+)").value_counts()

# %%
#df.upholstery.str.extract(r"(.+),(.+)")[0]

# %%
#df.upholstery.str.extract(r"(.+),(.+)")[1].value_counts(dropna=False)

# %%
#uph_type = df.upholstery.str.extract(r"(.+),(.+)")[0].dropna().unique()
uph_type = ['Cloth', 'Part leather', 'Full leather', 'Other', 'alcantara',
       'Velour']

# %%
#uph_color = df.upholstery.str.extract(r"(.+),(.+)")[1].dropna().unique()
uph_color = ['Black', 'Grey', 'White', 'Red', 'Blue', 'Orange',
       'Brown', 'Beige', 'Yellow']

# %%
#uph_type_color_column("upholstery")

# %%
a_type = df.upholstery.str.split(",").str[0]
a_type
# Out:
# 0               Cloth
# 1               Cloth
# 2               Cloth
# 3                 NaN
# 4               Cloth
#              ...
# 15914             NaN
# 15915           Cloth
# 15916    Full leather
# 15917    Part leather
# 15918    Full leather
# Name: upholstery, Length: 15042, dtype: object

# %%
a_type.value_counts(dropna=False)
# Out:
# Cloth           8135
# NaN             3561
# Part leather    1386
# Full leather     976
# Black            357
# Other            337
# Grey             156
# Velour            60
# alcantara         57
# Brown             12
# Blue               2
# White              2
# Beige              1
# Name: upholstery, dtype: int64

# %%
a_color = a_type[a_type.isin(uph_color)]
a_color
# Out:
# 29       Black
# 64       Black
# 112      Black
# 180       Grey
# 194       Blue
#          ...
# 15716    Black
# 15777    Brown
# 15866    Brown
# 15896     Grey
# 15902    Brown
# Name: upholstery, Length: 530, dtype: object

# %%
b_color = df.upholstery.str.split(",").str[1]
b_color
# Out:
# 0         Black
# 1          Grey
# 2         Black
# 3           NaN
# 4         Black
#           ...
# 15914       NaN
# 15915       NaN
# 15916     Black
# 15917       NaN
# 15918     Brown
# Name: upholstery, Length: 15042, dtype: object

# %%
b_color.fillna(a_color, inplace=True)

# %%
a_type[a_type.isin(uph_color)] = np.nan

# %%
df["upholstery_type"] = a_type
df["upholstery_color"] = b_color

# %%
df["upholstery_type"]
# Out:
# 0               Cloth
# 1               Cloth
# 2               Cloth
# 3                 NaN
# 4               Cloth
#              ...
# 15914             NaN
# 15915           Cloth
# 15916    Full leather
# 15917    Part leather
# 15918    Full leather
# Name: upholstery_type, Length: 15042, dtype: object

# %%
df[["upholstery","upholstery_type", "upholstery_color"]].sample(60)
# Out:
#                 upholstery upholstery_type upholstery_color
# 12670                Cloth           Cloth              NaN
# 12557   Part leather, Grey    Part leather             Grey
# 11484         Cloth, Black           Cloth            Black
# 8356          Cloth, Black           Cloth            Black
# 11681         Full leather    Full leather              NaN
# 14715                  NaN             NaN              NaN
# 3364                   NaN             NaN              NaN
# 12589  Full leather, Black    Full leather            Black
# 3918          Cloth, Black           Cloth            Black
# 9536          Cloth, Black           Cloth            Black
# 14779          Cloth, Grey           Cloth             Grey
# 15383         Full leather    Full leather              NaN
# 1343          Cloth, Black           Cloth            Black
# 2828          Cloth, Black           Cloth            Black
# 1490          Other, Black           Other            Black
# ...

# %%
df[["upholstery_type", "upholstery_color"]].isnull().sum()
# Out:
# upholstery_type     4091
# upholstery_color    4872
# dtype: int64

# %%
df.upholstery_color.notna().sum()
# Out:
# 10170

# %%
df.upholstery_type.notna().sum()
# Out:
# 10951

# %%
df[['upholstery_type']].info()
df[['upholstery_color']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15042 entries, 0 to 15918
# Data columns (total 1 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   upholstery_type  10951 non-null  object
# dtypes: object(1)
# memory usage: 235.0+ KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15042 entries, 0 to 15918
# Data columns (total 1 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   upholstery_color  10170 non-null  object
# dtypes: object(1)
# memory usage: 235.0+ KB

# %%
df.drop(columns="upholstery", inplace=True)

# %%
df.columns
# Out:
# Index(['make_model', 'short_description', 'body_type', 'price', 'vat', 'km',
#        'prev_owner', 'type', 'previous_owners', 'next_inspection',
#        'inspection_new', 'warranty', 'full_service', 'non_smoking_vehicle',
#        'first_registration', 'body_color', 'paint_type', 'body_color_original',
#        'nr_of_doors', 'nr_of_seats', 'model_code', 'gearing_type',
#        'displacement', 'cylinders', 'weight', 'drive_chain', 'fuel',
#        'consumption', 'co_2_emission', 'emission_class',
#        'comfort_&_convenience', 'entertainment_&_media', 'extras',
#        'safety_&_security', 'description', 'emission_label', 'gears',
#        'country_version', 'hp_kw', 'next_insp_date', 'insp_new',
#        'warranty_month', 'upholstery_type', 'upholstery_color'],
#       dtype='object')

# %% [markdown]
# ### nr_of_doors column

# %%
first_look("nr_of_doors")
# Out:
# column name :  nr_of_doors
# --------------------------------
# Per_of_Nulls   :  % 0.97
# Num_of_Nulls   :  146
# Num_of_Uniques :  6
# 5      11005
# 4       2872
# 3        823
# 2        194
# NaN      146
# 1          1
# 7          1
# Name: nr_of_doors, dtype: int64
# 1          1
# 2        194
# 3        823
# 4       2872
# 5      11005
# 7          1
# NaN      146
# Name: nr_of_doors, dtype: int64
# ########################################

# %%
df["nr_of_doors"] = df.nr_of_doors.astype(float)

# %% [markdown]
# ### nr_of_seats column

# %%
first_look("nr_of_seats")
# Out:
# column name :  nr_of_seats
# --------------------------------
# Per_of_Nulls   :  % 5.95
# Num_of_Nulls   :  895
# Num_of_Uniques :  6
# 5      12643
# 4       1088
# NaN      895
# 7        317
# 2         96
# 6          2
# 3          1
# Name: nr_of_seats, dtype: int64
# 2         96
# 3          1
# 4       1088
# 5      12643
# 6          2
# 7        317
# NaN      895
# Name: nr_of_seats, dtype: int64
# ########################################

# %%
df["nr_of_seats"] = df.nr_of_seats.astype(float)

# %% [markdown]
# ### model_code column

# %%
first_look("model_code")
# Out:
# column name :  model_code
# --------------------------------
# Per_of_Nulls   :  % 67.83
# Num_of_Nulls   :  10203
# Num_of_Uniques :  232
# NaN         10203
# 0035/BCB      266
# 0588/BNO      232
# 0588/BDB      203
# 0588/BHX      178
#             ...
# 0035/AVN        1
# 0035/BEM        1
# 0035/BAG        1
# 0035/BAA        1
# 3333/BKG        1
# Name: model_code, Length: 233, dtype: int64
# 0000/000       21
# 0000/035        1
# 0000/ACP        1
# 0035/AAA        1
# 0035/AAD        1
#             ...
# 3333/BJR       79
# 3333/BKG        1
# 3333/BKQ       18
# 3333/BKR        8
# NaN         10203
# Name: model_code, Length: 233, dtype: int64
# ########################################

# %%
df.drop(columns= "model_code", inplace=True)

# %%
df.shape
# Out:
# (15042, 43)

# %% [markdown]
# ### gearing_type

# %%
first_look("gearing_type")
# Out:
# column name :  gearing_type
# --------------------------------
# Per_of_Nulls   :  % 0.0
# Num_of_Nulls   :  0
# Num_of_Uniques :  3
# Manual            7672
# Automatic         6903
# Semi-automatic     467
# Name: gearing_type, dtype: int64
# Automatic         6903
# Manual            7672
# Semi-automatic     467
# Name: gearing_type, dtype: int64
# ########################################

# %% [markdown]
# ### displacement column

# %%
first_look("displacement")
# Out:
# column name :  displacement
# --------------------------------
# Per_of_Nulls   :  % 2.64
# Num_of_Nulls   :  397
# Num_of_Uniques :  77
# 1,598 cc    4524
# 999 cc      2383
# 1,398 cc    1288
# 1,399 cc     680
# 1,229 cc     673
#             ...
# 122 cc         1
# 1,198 cc       1
# 1,195 cc       1
# 2,967 cc       1
# 1,800 cc       1
# Name: displacement, Length: 78, dtype: int64
# 1 cc          36
# 1,000 cc      40
# 1,100 cc       1
# 1,149 cc     260
# 1,195 cc       1
#             ...
# 996 cc         1
# 997 cc         4
# 998 cc        72
# 999 cc      2383
# NaN          397
# Name: displacement, Length: 78, dtype: int64
# ########################################

# %%
df["displacement"] = df.displacement.str.replace(",","").str.extract(r"(\d+)").astype(float)

# %%
df["displacement"].value_counts()
# Out:
# 1598.0    4524
# 999.0     2383
# 1398.0    1288
# 1399.0     680
# 1229.0     673
#           ...
# 122.0        1
# 1198.0       1
# 1195.0       1
# 2967.0       1
# 1800.0       1
# Name: displacement, Length: 77, dtype: int64

# %%
df.rename(columns = {'displacement':'displacement_cc'}, inplace = True)

# %%
df.columns
# Out:
# Index(['make_model', 'short_description', 'body_type', 'price', 'vat', 'km',
#        'prev_owner', 'type', 'previous_owners', 'next_inspection',
#        'inspection_new', 'warranty', 'full_service', 'non_smoking_vehicle',
#        'first_registration', 'body_color', 'paint_type', 'body_color_original',
#        'nr_of_doors', 'nr_of_seats', 'gearing_type', 'displacement_cc',
#        'cylinders', 'weight', 'drive_chain', 'fuel', 'consumption',
#        'co_2_emission', 'emission_class', 'comfort_&_convenience',
#        'entertainment_&_media', 'extras', 'safety_&_security', 'description',
#        'emission_label', 'gears', 'country_version', 'hp_kw', 'next_insp_date',
#        'insp_new', 'warranty_month', 'upholstery_type', 'upholstery_color'],
#       dtype='object')

# %% [markdown]
# ### cylinders column

# %%
first_look("cylinders")
# Out:
# column name :  cylinders
# --------------------------------
# Per_of_Nulls   :  % 35.0
# Num_of_Nulls   :  5265
# Num_of_Uniques :  7
# 4      7681
# NaN    5265
# 3      2066
# 5        22
# 6         3
# 8         2
# 2         2
# 1         1
# Name: cylinders, dtype: int64
# 1         1
# 2         2
# 3      2066
# 4      7681
# 5        22
# 6         3
# 8         2
# NaN    5265
# Name: cylinders, dtype: int64
# ########################################

# %%
df["cylinders"] = df.cylinders.astype(float)

# %% [markdown]
# ### weight column

# %%
first_look("weight")
# Out:
# column name :  weight
# --------------------------------
# Per_of_Nulls   :  % 43.6
# Num_of_Nulls   :  6558
# Num_of_Uniques :  434
# NaN         6558
# 1,163 kg     561
# 1,360 kg     332
# 1,165 kg     276
# 1,335 kg     242
#             ...
# 1,213 kg       1
# 1,960 kg       1
# 1,258 kg       1
# 1,167 kg       1
# 2,037 kg       1
# Name: weight, Length: 435, dtype: int64
# 1 kg           2
# 1,009 kg       1
# 1,010 kg       3
# 1,017 kg       1
# 1,030 kg       1
#             ...
# 840 kg         1
# 900 kg         1
# 977 kg         2
# 980 kg        11
# NaN         6558
# Name: weight, Length: 435, dtype: int64
# ########################################

# %%
df["weight_kg"] = df.weight.str.replace(",","").str.extract(r"(\d+)").astype(float)

# %%
df["weight_kg"].value_counts(dropna=False)
# Out:
# NaN       6558
# 1163.0     561
# 1360.0     332
# 1165.0     276
# 1335.0     242
#           ...
# 1213.0       1
# 1960.0       1
# 1258.0       1
# 1167.0       1
# 2037.0       1
# Name: weight_kg, Length: 435, dtype: int64

# %%
df.drop(columns="weight", inplace=True)

# %%
df.columns
# Out:
# Index(['make_model', 'short_description', 'body_type', 'price', 'vat', 'km',
#        'prev_owner', 'type', 'previous_owners', 'next_inspection',
#        'inspection_new', 'warranty', 'full_service', 'non_smoking_vehicle',
#        'first_registration', 'body_color', 'paint_type', 'body_color_original',
#        'nr_of_doors', 'nr_of_seats', 'gearing_type', 'displacement_cc',
#        'cylinders', 'drive_chain', 'fuel', 'consumption', 'co_2_emission',
#        'emission_class', 'comfort_&_convenience', 'entertainment_&_media',
#        'extras', 'safety_&_security', 'description', 'emission_label', 'gears',
#        'country_version', 'hp_kw', 'next_insp_date', 'insp_new',
#        'warranty_month', 'upholstery_type', 'upholstery_color', 'weight_kg'],
#       dtype='object')

# %% [markdown]
# ### drive_chain column

# %%
first_look("drive_chain")
# Out:
# column name :  drive_chain
# --------------------------------
# Per_of_Nulls   :  % 43.12
# Num_of_Nulls   :  6486
# Num_of_Uniques :  3
# front    8400
# NaN      6486
# 4WD       152
# rear        4
# Name: drive_chain, dtype: int64
# 4WD       152
# front    8400
# rear        4
# NaN      6486
# Name: drive_chain, dtype: int64
# ########################################

# %% [markdown]
# ### fuel column

# %%
first_look("fuel")
# Out:
# column name :  fuel
# --------------------------------
# Per_of_Nulls   :  % 0.0
# Num_of_Nulls   :  0
# Num_of_Uniques :  77
# Diesel (Particulate Filter)                                                                                  4032
# Super 95                                                                                                     3219
# Gasoline                                                                                                     2956
# Diesel                                                                                                       2826
# Super 95 / Regular/Benzine 91                                                                                 418
#                                                                                                              ...
# Regular/Benzine 91 / Super 95 / Regular/Benzine E10 91                                                          1
# ...

# %%
get_diff_category_column(df.fuel)
# Out:
# {0: 'Biodiesel',
#  1: 'Biogas',
#  2: 'CNG',
#  3: 'CNG (Particulate Filter)',
#  4: 'Diesel',
#  5: 'Diesel (Particulate Filter)',
#  6: 'Domestic gas H',
#  7: 'Electric',
#  8: 'Electric/Gasoline',
#  9: 'Gasoline',
#  10: 'Gasoline (Particulate Filter)',
#  11: 'LPG',
#  12: 'Liquid petroleum gas (LPG)',
#  13: 'Others',
#  14: 'Others (Particulate Filter)',
#  15: 'Regular/Benzine 91',
#  16: 'Regular/Benzine 91 (Particulate Filter)',
#  17: 'Regular/Benzine E10 91',
#  18: 'Regular/Benzine E10 91 (Particulate Filter)',
#  19: 'Super 95',
#  20: 'Super 95 (Particulate Filter)',
#  21: 'Super E10 95',
#  22: 'Super E10 95 (Particulate Filter)',
#  23: 'Super Plus 98',
#  24: 'Super Plus 98 (Particulate Filter)',
#  25: 'Super Plus E10 98',
#  26: 'Super Plus E10 98 (Particulate Filter)'}

# %%
benzine = ["Gasoline", "Super 95", "Regular","Super E10 95","Super Plus 98","Super Plus E10 98", "Others"]
diesel = ["Biodiesel","Diesel"]
lpg = ["Biogas", "Domestic gas H", "LPG","Liquid petroleum gas", "CNG"]
electric = ['Electric', 'Electric/Gasoline']

def fueltype(x):
    if any(i in x for i in electric):
        return "Electric"
    elif any(i in x for i in lpg):
        return "LPG/CNG"
    elif any(i in x for i in benzine):
        return "Benzine"
    elif any(i in x for i in diesel):
        return "Diesel"
    else:
        return x
    
df["fuel"].apply(fueltype).value_counts()
# Out:
# Benzine     8118
# Diesel      6858
# LPG/CNG       61
# Electric       5
# Name: fuel, dtype: int64

# %%
df["fuel"] = df["fuel"].apply(fueltype)

# %%
df.columns
# Out:
# Index(['make_model', 'short_description', 'body_type', 'price', 'vat', 'km',
#        'prev_owner', 'type', 'previous_owners', 'next_inspection',
#        'inspection_new', 'warranty', 'full_service', 'non_smoking_vehicle',
#        'first_registration', 'body_color', 'paint_type', 'body_color_original',
#        'nr_of_doors', 'nr_of_seats', 'gearing_type', 'displacement_cc',
#        'cylinders', 'drive_chain', 'fuel', 'consumption', 'co_2_emission',
#        'emission_class', 'comfort_&_convenience', 'entertainment_&_media',
#        'extras', 'safety_&_security', 'description', 'emission_label', 'gears',
#        'country_version', 'hp_kw', 'next_insp_date', 'insp_new',
#        'warranty_month', 'upholstery_type', 'upholstery_color', 'weight_kg'],
#       dtype='object')

# %% [markdown]
# ### consumption column

# %% [markdown]
# #### Split the "consumption" column

# %% [markdown]
# ##### First Method

# %%
# erase some characters with replace methods in "consumption" column
new_columns = ["consumption_comb","consumption_city","consumption_country"]
df["consumption"]=df["consumption"].str.replace("\n,","")

# split the "consumption" column
df[new_columns]=df["consumption"].str.split(",",expand=True).loc[:,:2].applymap(lambda x : np.nan if x == "[]" or  x == "\n" else x)

# checking values of the new columns
print("count of null values in the comb columns\t:",len(df)-df["consumption"].str.contains("comb").sum())
print("count of null values in the city columns\t:",len(df)-df["consumption"].str.contains("city").sum())
print("count of null values in the country columns\t:",len(df)-df["consumption"].str.contains("country").sum())
df[new_columns].isnull().sum()
# Out:
# count of null values in the comb columns	: 1948
# count of null values in the city columns	: 2344
# count of null values in the country columns	: 2284
# consumption_comb       1821
# consumption_city       3165
# consumption_country    3232
# dtype: int64

# %%
for i in df[new_columns]:
    df[i] = df[i].str.extract(r"(\d*\.\d+|\d+)")
df[new_columns].isnull().sum()
# Out:
# consumption_comb       1821
# consumption_city       3165
# consumption_country    3232
# dtype: int64

# %% [markdown]
# ##### Second Method

# %%
# parsing the "consumption" column
# df["consumption"]=df["consumption"].str.replace("\n,","").str.replace("[\[\]']?","")
# df["comb"]=df["consumption"].str.findall(".+comb\)").transform(lambda x : np.nan if x == [] else x)
# df["city"]=df["consumption"].str.findall("[.+]?,(\d.+city\))").transform(lambda x : np.nan if x == [] else x)
# df["country"]=df["consumption"].str.findall(".+,(\d.+country\))").transform(lambda x : np.nan if x == [] else x)

# print("count of null values in the comb columns\t:",len(df)-df["consumption"].str.contains("comb").sum())
# print("count of null values in the city columns\t:",len(df)-df["consumption"].str.contains("city").sum())
# print("count of null values in the country columns\t:",len(df)-df["consumption"].str.contains("country").sum())
# df[["comb","city","country"]].isnull().sum()

# %%
df["consumption_city"] = df.consumption_city.astype(float)

# %%
df["consumption_country"]= df.consumption_country.astype(float)

# %%
df["consumption_comb"] = df.consumption_comb.astype(float)

# %%
df[["consumption_comb","consumption_city","consumption_country"]].isnull().sum()
# Out:
# consumption_comb       1821
# consumption_city       3165
# consumption_country    3232
# dtype: int64

# %%
df.drop(columns="consumption", inplace=True)

# %% [markdown]
# ### co_2_emission column

# %%
first_look("co_2_emission")
# Out:
# column name :  co_2_emission
# --------------------------------
# Per_of_Nulls   :  % 15.34
# Num_of_Nulls   :  2307
# Num_of_Uniques :  122
# NaN                      2307
# 120 g CO2/km (comb)       666
# 99 g CO2/km (comb)        537
# 97 g CO2/km (comb)        512
# 102 g CO2/km (comb)       471
#                          ...
# 14 g CO2/km (comb)          1
# 1,060 g CO2/km (comb)       1
# 51 g CO2/km (comb)          1
# 165 g CO2/km (comb)         1
# 193 g CO2/km (comb)         1
# Name: co_2_emission, Length: 123, dtype: int64
# 0 g CO2/km (comb)           2
# 1 g CO2/km (comb)           1
# 1,060 g CO2/km (comb)       1
# 100 g CO2/km (comb)        26
# 101 g CO2/km (comb)       103
#                          ...
# 97 g CO2/km (comb)        512
# 98 g CO2/km (comb)        148
# 99 g CO2/km (comb)        537
# 990 g CO2/km (comb)         1
# NaN                      2307
# Name: co_2_emission, Length: 123, dtype: int64
# ########################################

# %%
df.co_2_emission.str.replace(",","")
# Out:
# 0         99 g CO2/km (comb)
# 1        129 g CO2/km (comb)
# 2         99 g CO2/km (comb)
# 3         99 g CO2/km (comb)
# 4        109 g CO2/km (comb)
#                 ...
# 15914    139 g CO2/km (comb)
# 15915    168 g CO2/km (comb)
# 15916    139 g CO2/km (comb)
# 15917    139 g CO2/km (comb)
# 15918    153 g CO2/km (comb)
# Name: co_2_emission, Length: 15042, dtype: object

# %%
df["co_2_emission"] = df.co_2_emission.str.replace(",","").str.extract(r"(\d+)").astype(float)

# %%
df.co_2_emission.notna().sum()
# Out:
# 12735

# %% [markdown]
# ### emission_class column

# %%
first_look("emission_class")
# Out:
# column name :  emission_class
# --------------------------------
# Per_of_Nulls   :  % 22.79
# Num_of_Nulls   :  3428
# Num_of_Uniques :  6
# Euro 6          9543
# NaN             3428
# Euro 6d-TEMP    1764
# Euro 6c          127
# Euro 5            78
# Euro 6d           62
# Euro 4            40
# Name: emission_class, dtype: int64
# Euro 4            40
# Euro 5            78
# Euro 6          9543
# Euro 6c          127
# Euro 6d           62
# Euro 6d-TEMP    1764
# NaN             3428
# Name: emission_class, dtype: int64
# ########################################

# %% [markdown]
# ### comfort_&_convenience column

# %%
first_look("comfort_&_convenience")
# Out:
# column name :  comfort_&_convenience
# --------------------------------
# Per_of_Nulls   :  % 5.37
# Num_of_Nulls   :  808
# Num_of_Uniques :  6198
# NaN                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  808
# ...

# %%
get_diff_category_column(df["comfort_&_convenience"])
# Out:
# {0: 'Air conditioning',
#  1: 'Air suspension',
#  2: 'Armrest',
#  3: 'Automatic climate control',
#  4: 'Auxiliary heating',
#  5: 'Cruise control',
#  6: 'Electric Starter',
#  7: 'Electric tailgate',
#  8: 'Electrical side mirrors',
#  9: 'Electrically adjustable seats',
#  10: 'Electrically heated windshield',
#  11: 'Heads-up display',
#  12: 'Heated steering wheel',
#  13: 'Hill Holder',
#  14: 'Keyless central door lock',
#  15: 'Leather seats',
#  16: 'Leather steering wheel',
#  17: 'Light sensor',
#  18: 'Lumbar support',
#  19: 'Massage seats',
#  20: 'Multi-function steering wheel',
#  21: 'Navigation system',
#  22: 'Panorama roof',
#  23: 'Park Distance Control',
#  24: 'Parking assist system camera',
#  25: 'Parking assist system self-steering',
#  26: 'Parking assist system sensors front',
#  27: 'Parking assist system sensors rear',
#  28: 'Power windows',
#  29: 'Rain sensor',
#  30: 'Seat heating',
#  31: 'Seat ventilation',
#  32: 'Split rear seats',
# ...

# %%
df.rename(columns = {'comfort_&_convenience':'comfort_convenience'}, inplace = True)

# %%
df.columns
# Out:
# Index(['make_model', 'short_description', 'body_type', 'price', 'vat', 'km',
#        'prev_owner', 'type', 'previous_owners', 'next_inspection',
#        'inspection_new', 'warranty', 'full_service', 'non_smoking_vehicle',
#        'first_registration', 'body_color', 'paint_type', 'body_color_original',
#        'nr_of_doors', 'nr_of_seats', 'gearing_type', 'displacement_cc',
#        'cylinders', 'drive_chain', 'fuel', 'co_2_emission', 'emission_class',
#        'comfort_convenience', 'entertainment_&_media', 'extras',
#        'safety_&_security', 'description', 'emission_label', 'gears',
#        'country_version', 'hp_kw', 'next_insp_date', 'insp_new',
#        'warranty_month', 'upholstery_type', 'upholstery_color', 'weight_kg',
#        'consumption_comb', 'consumption_city', 'consumption_country'],
#       dtype='object')

# %% [markdown]
# ### entertainment_&_media column

# %%
first_look("entertainment_&_media")
# Out:
# column name :  entertainment_&_media
# --------------------------------
# Per_of_Nulls   :  % 8.0
# Num_of_Nulls   :  1204
# Num_of_Uniques :  346
# Bluetooth,Hands-free equipment,On-board computer,Radio,USB                                     1246
# NaN                                                                                            1204
# Bluetooth,Hands-free equipment,MP3,On-board computer,Radio,USB                                  969
# Bluetooth,CD player,Hands-free equipment,MP3,On-board computer,Radio,USB                        769
# Radio                                                                                           461
#                                                                                                ...
# Bluetooth,CD player,Digital radio,Hands-free equipment,On-board computer,Radio,Sound system       1
# Bluetooth,Sound system,USB                                                                        1
# ...

# %%
get_diff_category_column(df["entertainment_&_media"])
# Out:
# {0: 'Bluetooth',
#  1: 'CD player',
#  2: 'Digital radio',
#  3: 'Hands-free equipment',
#  4: 'MP3',
#  5: 'On-board computer',
#  6: 'Radio',
#  7: 'Sound system',
#  8: 'Television',
#  9: 'USB'}

# %%
df.rename(columns = {'entertainment_&_media':'entertainment_media'}, inplace = True)

# %%
df.columns
# Out:
# Index(['make_model', 'short_description', 'body_type', 'price', 'vat', 'km',
#        'prev_owner', 'type', 'previous_owners', 'next_inspection',
#        'inspection_new', 'warranty', 'full_service', 'non_smoking_vehicle',
#        'first_registration', 'body_color', 'paint_type', 'body_color_original',
#        'nr_of_doors', 'nr_of_seats', 'gearing_type', 'displacement_cc',
#        'cylinders', 'drive_chain', 'fuel', 'co_2_emission', 'emission_class',
#        'comfort_convenience', 'entertainment_media', 'extras',
#        'safety_&_security', 'description', 'emission_label', 'gears',
#        'country_version', 'hp_kw', 'next_insp_date', 'insp_new',
#        'warranty_month', 'upholstery_type', 'upholstery_color', 'weight_kg',
#        'consumption_comb', 'consumption_city', 'consumption_country'],
#       dtype='object')

# %% [markdown]
# ### extras column

# %%
first_look("extras")
# Out:
# column name :  extras
# --------------------------------
# Per_of_Nulls   :  % 18.17
# Num_of_Nulls   :  2733
# Num_of_Uniques :  659
# Alloy wheels                                                                                               2977
# NaN                                                                                                        2733
# Alloy wheels,Touch screen                                                                                   656
# Alloy wheels,Voice Control                                                                                  548
# Alloy wheels,Touch screen,Voice Control                                                                     516
#                                                                                                            ...
# Alloy wheels,Catalytic Converter,Shift paddles,Sport package,Sport seats,Sport suspension,Voice Control       1
# ...

# %%
get_diff_category_column(df["extras"])
# Out:
# {0: 'Alloy wheels',
#  1: 'Cab or rented Car',
#  2: 'Catalytic Converter',
#  3: 'Handicapped enabled',
#  4: 'Right hand drive',
#  5: 'Roof rack',
#  6: 'Shift paddles',
#  7: 'Ski bag',
#  8: 'Sliding door',
#  9: 'Sport package',
#  10: 'Sport seats',
#  11: 'Sport suspension',
#  12: 'Touch screen',
#  13: 'Trailer hitch',
#  14: 'Tuned car',
#  15: 'Voice Control',
#  16: 'Winter tyres'}

# %% [markdown]
# ### safety_&_security column

# %%
first_look("safety_&_security")
# Out:
# column name :  safety_&_security
# --------------------------------
# Per_of_Nulls   :  % 5.65
# Num_of_Nulls   :  850
# Num_of_Uniques :  4443
# NaN                                                                                                                                                                                                                                                                                                                                                               850
# ABS,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Fog lights,Immobilizer,Isofix,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control                                                                                                                                      502
# ...

# %%
get_diff_category_column(df["safety_&_security"])
# Out:
# {0: 'ABS',
#  1: 'Adaptive Cruise Control',
#  2: 'Adaptive headlights',
#  3: 'Alarm system',
#  4: 'Blind spot monitor',
#  5: 'Central door lock',
#  6: 'Central door lock with remote control',
#  7: 'Daytime running lights',
#  8: 'Driver drowsiness detection',
#  9: 'Driver-side airbag',
#  10: 'Electronic stability control',
#  11: 'Emergency brake assistant',
#  12: 'Emergency system',
#  13: 'Fog lights',
#  14: 'Head airbag',
#  15: 'Immobilizer',
#  16: 'Isofix',
#  17: 'LED Daytime Running Lights',
#  18: 'LED Headlights',
#  19: 'Lane departure warning system',
#  20: 'Night view assist',
#  21: 'Passenger-side airbag',
#  22: 'Power steering',
#  23: 'Rear airbag',
#  24: 'Side airbag',
#  25: 'Tire pressure monitoring system',
#  26: 'Traction control',
#  27: 'Traffic sign recognition',
#  28: 'Xenon headlights'}

# %%
df.rename(columns = {'safety_&_security':'safety_security'}, inplace = True)

# %% [markdown]
# ### description column

# %%
first_look("description")
# Out:
# column name :  description
# --------------------------------
# Per_of_Nulls   :  % 4.16
# Num_of_Nulls   :  625
# Num_of_Uniques :  12849
# ...

# %%
df.drop(columns="description", inplace=True)

# %%
df.columns
# Out:
# Index(['make_model', 'short_description', 'body_type', 'price', 'vat', 'km',
#        'prev_owner', 'type', 'previous_owners', 'next_inspection',
#        'inspection_new', 'warranty', 'full_service', 'non_smoking_vehicle',
#        'first_registration', 'body_color', 'paint_type', 'body_color_original',
#        'nr_of_doors', 'nr_of_seats', 'gearing_type', 'displacement_cc',
#        'cylinders', 'drive_chain', 'fuel', 'co_2_emission', 'emission_class',
#        'comfort_convenience', 'entertainment_media', 'extras',
#        'safety_security', 'emission_label', 'gears', 'country_version',
#        'hp_kw', 'next_insp_date', 'insp_new', 'warranty_month',
#        'upholstery_type', 'upholstery_color', 'weight_kg', 'consumption_comb',
#        'consumption_city', 'consumption_country'],
#       dtype='object')

# %%
df.shape
# Out:
# (15042, 44)

# %% [markdown]
# ### emission_label column

# %%
first_look("emission_label")
# Out:
# column name :  emission_label
# --------------------------------
# Per_of_Nulls   :  % 75.86
# Num_of_Nulls   :  11411
# Num_of_Uniques :  5
# NaN               11411
# 4 (Green)          3263
# 1 (No sticker)      357
# 5 (Blue)              8
# 3 (Yellow)            2
# 2 (Red)               1
# Name: emission_label, dtype: int64
# 1 (No sticker)      357
# 2 (Red)               1
# 3 (Yellow)            2
# 4 (Green)          3263
# 5 (Blue)              8
# NaN               11411
# Name: emission_label, dtype: int64
# ########################################

# %% [markdown]
# ### gears column

# %%
first_look("gears")
# Out:
# column name :  gears
# --------------------------------
# Per_of_Nulls   :  % 28.85
# Num_of_Nulls   :  4340
# Num_of_Uniques :  10
# 6      5490
# NaN    4340
# 5      3138
# 7      1844
# 8       216
# 9         6
# 1         2
# 3         2
# 4         2
# 2         1
# 50        1
# Name: gears, dtype: int64
# 1         2
# 2         1
# 3         2
# 4         2
# 5      3138
# 50        1
# 6      5490
# 7      1844
# 8       216
# 9         6
# NaN    4340
# Name: gears, dtype: int64
# ########################################

# %%
df["gears"] = df.gears.astype(float)

# %% [markdown]
# ### country_version column

# %%
first_look("country_version")
# Out:
# column name :  country_version
# --------------------------------
# Per_of_Nulls   :  % 51.79
# Num_of_Nulls   :  7791
# Num_of_Uniques :  23
# NaN               7791
# Germany           4246
# Italy             1037
# Netherlands        464
# European Union     446
# Spain              318
# Belgium            314
# Austria            207
# Czech Republic      52
# Poland              40
# France              38
# Denmark             33
# Hungary             28
# Japan                8
# Slovakia             4
# Croatia              4
# Sweden               3
# Romania              2
# Bulgaria             2
# Luxembourg           1
# Switzerland          1
# Slovenia             1
# Egypt                1
# Serbia               1
# Name: country_version, dtype: int64
# Austria            207
# Belgium            314
# Bulgaria             2
# Croatia              4
# Czech Republic      52
# Denmark             33
# Egypt                1
# European Union     446
# ...

# %%
#Since there is no info and impact about our target column, price, we drop it:
df.drop(columns="country_version", inplace=True)

# %%
df.columns
# Out:
# Index(['make_model', 'short_description', 'body_type', 'price', 'vat', 'km',
#        'prev_owner', 'type', 'previous_owners', 'next_inspection',
#        'inspection_new', 'warranty', 'full_service', 'non_smoking_vehicle',
#        'first_registration', 'body_color', 'paint_type', 'body_color_original',
#        'nr_of_doors', 'nr_of_seats', 'gearing_type', 'displacement_cc',
#        'cylinders', 'drive_chain', 'fuel', 'co_2_emission', 'emission_class',
#        'comfort_convenience', 'entertainment_media', 'extras',
#        'safety_security', 'emission_label', 'gears', 'hp_kw', 'next_insp_date',
#        'insp_new', 'warranty_month', 'upholstery_type', 'upholstery_color',
#        'weight_kg', 'consumption_comb', 'consumption_city',
#        'consumption_country'],
#       dtype='object')

# %%
df.shape
# Out:
# (15042, 43)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15042 entries, 0 to 15918
# Data columns (total 43 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   make_model           15042 non-null  object
#  1   short_description    14993 non-null  object
#  2   body_type            14992 non-null  object
#  3   price                15042 non-null  float64
#  4   vat                  10953 non-null  object
#  5   km                   14073 non-null  float64
#  6   prev_owner           8647 non-null   float64
#  7   type                 15040 non-null  object
#  8   previous_owners      8834 non-null   object
#  9   next_inspection      3436 non-null   object
#  10  inspection_new       3811 non-null   object
#  11  warranty             8728 non-null   object
#  12  full_service         5852 non-null   object
#  13  non_smoking_vehicle  3023 non-null   object
#  14  first_registration   13547 non-null  float64
# ...

# %%
df.to_csv("clean_scout.csv", index=False)

# %% [markdown]
# # PART- 2 `( Handling With Missing Values )`

# %%
# In the 2nd notebook we handle with missing values.

# %% [markdown]
# # PART- 3 `( Handling With Outliers )`

# %%
# In the 3rd notebook we handle with outliers.

# %% [markdown]
# # Final Step (Checking final situation of data via graphs)

# %% [markdown]
# ## Export dataframe to csv file (without dummy)

# %%
#df.to_csv("final_scout_not_dummy.csv", index=False)

# %% [markdown]
# # Dummy Operation

# %% [markdown]
# ## Export dataframe to csv file (dummy)

# %%
#df_dummied.to_csv("final_scout_dummy.csv", index=False)
